# %% [markdown]
# #common

# %%
dbutils.widgets.text("databricks_database","catalog_southeastasia_mdm_golden_prod.consumer_master")
dbutils.widgets.text("databricks_cbr_database","catalog_southeastasia_mdm_golden_prod.consumer_combine")

# %%
talend_snapshot_path = "abfss://bronze@saapseaprodacdgen2.dfs.core.windows.net/cdp_mdm_prod/history_data_loading/Prod_Consumer_20260715"

order_cols = "scon_id,scon_srcc_id,scon_srcc_action,consumermdmkey,scon_srcs_code,scon_sourcetimestamp,scon_mrkt_code,scon_aff_code,scon_dvsn_code,scon_brnd_code,scon_consumerid,scon_salutation,scon_englishfirstname,scon_englishmiddlename,scon_englishlastname,scon_englishfullname,scon_localfirstname,scon_localmiddlename,scon_locallastname,scon_localfullname,scon_localfirstname2,scon_localmiddlename2,scon_locallastname2,scon_localfullname2,scon_gndr_code,scon_birthday,scon_birthmonth,scon_birthyear,scon_identitynum,scon_passportnum,scon_socialsecuritynum,scon_clas_code,scon_reg_dt,scon_registration_toch_code,scon_registration_prsn_code,scon_preferred_toch_code,scon_assigned_prsn_code,scon_wlng_code,scon_slng_code,scon_cntr_isoalpha3code,scon_ethn_code,scon_sknt_code,scon_hairt_code,scon_cvls_code,scon_company,scon_department,scon_jobtitle,scon_yearlyincome,scon_donotcontact_flag,scon_curr_code,scon_agefrom,scon_ageto,scon_nationality,scon_channel,scon_preferred_comm_channel,scon_anniversary_dt,scon_commercial_flag,scon_emailreceipt_flag,scon_prospect_flag,scon_active_flag,scon_hrrequesttimestamp,scon_status,scon_creation_dt,scon_creation_uid,scon_update_dt,scon_update_uid,scon_cbr_flag,scon_firstpurchasedate,scon_delete_flag,scon_englishname_quality_code,scon_localname_quality_code,scon_localname2_quality_code,is_retain_for_history"
# SCON_MASTERCONSUMERID,SCON_SOURCESYSTEMCODE,SCON_UNIVERSALKEY,task_id,batch_id,is_retain_for_history

# all_talend_master_consumer_sql = f"""
# (
#       select 'AUS' as market_source, 'aus_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumer` 
#       union all
#       select 'HKG' as market_source, 'hkg_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumer` 
#       union all
#       select 'IDN' as market_source, 'idn_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumer` 
#       union all  
#       select 'JPN' as market_source, 'jpn_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumer` 
#       union all
#       select 'KOR' as market_source, 'kor_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumer` 
#       union all
#       select 'MYS' as market_source, 'mys_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumer` 
#       union all
#       select 'NZL' as market_source, 'nzl_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumer` 
#       union all
#       select 'PHL' as market_source, 'phl_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumer` 
#       union all
#       select 'SGP' as market_source, 'sgp_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumer` 
#       union all
#       select 'THA' as market_source, 'tha_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumer` 
#       union all
#       select 'TWN' as market_source, 'twn_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumer` 
#       union all
#       select 'VNM' as market_source, 'vnm_elcconsumermdm' as database_name, scon_mrkt_code from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumer` 
# )
# """

corss_talend_master_consumer_sql = f"""
      (
       select  'aus_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumer_cross_market`  union

       select  'hkg_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumer_cross_market`  union

       select  'idn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumer_cross_market`  union

       select  'jpn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumer_cross_market`  union

       select  'kor_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumer_cross_market`  union

       select  'mys_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumer_cross_market`  union

       select  'nzl_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumer_cross_market`  union

       select  'phl_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumer_cross_market`  union

       select  'sgp_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumer_cross_market`  union

       select  'tha_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumer_cross_market`  union

       select  'twn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumer_cross_market`  union

       select  'vnm_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumer_cross_market` 
      )
"""

spark.sql(corss_talend_master_consumer_sql).createOrReplaceGlobalTempView("corss_talend_master_consumer_tab")

# %%
get_all_talend_data_sql = """
(
 select  'aus_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/{table_name}` 
  union all
 select  'hkg_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/{table_name}` 
  union all
 select  'idn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/{table_name}` 
  union all  
 select  'jpn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/{table_name}` 
  union all
 select  'kor_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/{table_name}` 
  union all
 select  'mys_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/{table_name}` 
  union all
 select  'nzl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/{table_name}` 
  union all
 select  'phl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/{table_name}` 
  union all
-- select  'sgp_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/{table_name}` 
--  union all
select  'tha_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/{table_name}` 
  union all
-- select  'twn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/{table_name}` 
--  union all
 select  'vnm_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/{table_name}` 
)
"""


def get_talend_df(talend_snapshot_path, table_name):
    print(f"get_talend_df: {talend_snapshot_path} -> {table_name}")
    
    return spark.sql(get_all_talend_data_sql.format(talend_snapshot_path=talend_snapshot_path, table_name=table_name))

# %%
get_talend_cbr_data_sql = """
(
select  'aus_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/{table_name}` 
 union all
select  'hkg_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/{table_name}` 
 union all
select  'idn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/{table_name}` 
 union all  
select  'jpn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/{table_name}_inc` 
 union all
select  'kor_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/{table_name}` 
 union all
select  'mys_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/{table_name}` 
 union all
select  'nzl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/{table_name}` 
 union all
select  'phl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/{table_name}` 
 union all
select  'sgp_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/{table_name}` 
 union all
select  'tha_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/{table_name}` 
 union all
select  'twn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/{table_name}` 
union all
select  'vnm_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/{table_name}` 
)
"""


def get_talend_cbr_df(talend_snapshot_path, table_name):
    print(f"get_talend_df: {talend_snapshot_path} -> {table_name}")
    
    return spark.sql(get_talend_cbr_data_sql.format(talend_snapshot_path=talend_snapshot_path, table_name=table_name))

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM
  (select * FROM ${databricks_database}.t_master_consumer where SCON_MRKT_CODE not in ('SGP', 'TWN') )

  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCON_ID','is_null', `SCON_ID` IS NULL),
    named_struct('Column_Name','SCON_SRCC_ID','is_null', `SCON_SRCC_ID` IS NULL),
    named_struct('Column_Name','SCON_SRCC_ACTION','is_null', `SCON_SRCC_ACTION` IS NULL),
    named_struct('Column_Name','CONSUMERMDMKEY','is_null', `CONSUMERMDMKEY` IS NULL),
    named_struct('Column_Name','SCON_SRCS_CODE','is_null', `SCON_SRCS_CODE` IS NULL),
    named_struct('Column_Name','SCON_SOURCETIMESTAMP','is_null', `SCON_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCON_MRKT_CODE','is_null', `SCON_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCON_AFF_CODE','is_null', `SCON_AFF_CODE` IS NULL),
    named_struct('Column_Name','SCON_DVSN_CODE','is_null', `SCON_DVSN_CODE` IS NULL),
    named_struct('Column_Name','SCON_BRND_CODE','is_null', `SCON_BRND_CODE` IS NULL),
    named_struct('Column_Name','SCON_CONSUMERID','is_null', `SCON_CONSUMERID` IS NULL),
    named_struct('Column_Name','SCON_SALUTATION','is_null', `SCON_SALUTATION` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHFIRSTNAME','is_null', `SCON_ENGLISHFIRSTNAME` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHMIDDLENAME','is_null', `SCON_ENGLISHMIDDLENAME` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHLASTNAME','is_null', `SCON_ENGLISHLASTNAME` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHFULLNAME','is_null', `SCON_ENGLISHFULLNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALFIRSTNAME','is_null', `SCON_LOCALFIRSTNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALMIDDLENAME','is_null', `SCON_LOCALMIDDLENAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALLASTNAME','is_null', `SCON_LOCALLASTNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALFULLNAME','is_null', `SCON_LOCALFULLNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALFIRSTNAME2','is_null', `SCON_LOCALFIRSTNAME2` IS NULL),
    named_struct('Column_Name','SCON_LOCALMIDDLENAME2','is_null', `SCON_LOCALMIDDLENAME2` IS NULL),
    named_struct('Column_Name','SCON_LOCALLASTNAME2','is_null', `SCON_LOCALLASTNAME2` IS NULL),
    named_struct('Column_Name','SCON_LOCALFULLNAME2','is_null', `SCON_LOCALFULLNAME2` IS NULL),
    named_struct('Column_Name','SCON_GNDR_CODE','is_null', `SCON_GNDR_CODE` IS NULL),
    named_struct('Column_Name','SCON_BIRTHDAY','is_null', `SCON_BIRTHDAY` IS NULL),
    named_struct('Column_Name','SCON_BIRTHMONTH','is_null', `SCON_BIRTHMONTH` IS NULL),
    named_struct('Column_Name','SCON_BIRTHYEAR','is_null', `SCON_BIRTHYEAR` IS NULL),
    named_struct('Column_Name','SCON_IDENTITYNUM','is_null', `SCON_IDENTITYNUM` IS NULL),
    named_struct('Column_Name','SCON_PASSPORTNUM','is_null', `SCON_PASSPORTNUM` IS NULL),
    named_struct('Column_Name','SCON_SOCIALSECURITYNUM','is_null', `SCON_SOCIALSECURITYNUM` IS NULL),
    named_struct('Column_Name','SCON_CLAS_CODE','is_null', `SCON_CLAS_CODE` IS NULL),
    named_struct('Column_Name','SCON_REG_DT','is_null', `SCON_REG_DT` IS NULL),
    named_struct('Column_Name','SCON_REGISTRATION_TOCH_CODE','is_null', `SCON_REGISTRATION_TOCH_CODE` IS NULL),
    named_struct('Column_Name','SCON_REGISTRATION_PRSN_CODE','is_null', `SCON_REGISTRATION_PRSN_CODE` IS NULL),
    named_struct('Column_Name','SCON_PREFERRED_TOCH_CODE','is_null', `SCON_PREFERRED_TOCH_CODE` IS NULL),
    named_struct('Column_Name','SCON_ASSIGNED_PRSN_CODE','is_null', `SCON_ASSIGNED_PRSN_CODE` IS NULL),
    named_struct('Column_Name','SCON_WLNG_CODE','is_null', `SCON_WLNG_CODE` IS NULL),
    named_struct('Column_Name','SCON_SLNG_CODE','is_null', `SCON_SLNG_CODE` IS NULL),
    named_struct('Column_Name','SCON_CNTR_ISOALPHA3CODE','is_null', `SCON_CNTR_ISOALPHA3CODE` IS NULL),
    named_struct('Column_Name','SCON_ETHN_CODE','is_null', `SCON_ETHN_CODE` IS NULL),
    named_struct('Column_Name','SCON_SKNT_CODE','is_null', `SCON_SKNT_CODE` IS NULL),
    named_struct('Column_Name','SCON_HAIRT_CODE','is_null', `SCON_HAIRT_CODE` IS NULL),
    named_struct('Column_Name','SCON_CVLS_CODE','is_null', `SCON_CVLS_CODE` IS NULL),
    named_struct('Column_Name','SCON_COMPANY','is_null', `SCON_COMPANY` IS NULL),
    named_struct('Column_Name','SCON_DEPARTMENT','is_null', `SCON_DEPARTMENT` IS NULL),
    named_struct('Column_Name','SCON_JOBTITLE','is_null', `SCON_JOBTITLE` IS NULL),
    named_struct('Column_Name','SCON_YEARLYINCOME','is_null', `SCON_YEARLYINCOME` IS NULL),
    named_struct('Column_Name','SCON_DONOTCONTACT_FLAG','is_null', `SCON_DONOTCONTACT_FLAG` IS NULL),
    named_struct('Column_Name','SCON_CURR_CODE','is_null', `SCON_CURR_CODE` IS NULL),
    named_struct('Column_Name','SCON_AGEFROM','is_null', `SCON_AGEFROM` IS NULL),
    named_struct('Column_Name','SCON_AGETO','is_null', `SCON_AGETO` IS NULL),
    named_struct('Column_Name','SCON_NATIONALITY','is_null', `SCON_NATIONALITY` IS NULL),
    named_struct('Column_Name','SCON_CHANNEL','is_null', `SCON_CHANNEL` IS NULL),
    named_struct('Column_Name','SCON_PREFERRED_COMM_CHANNEL','is_null', `SCON_PREFERRED_COMM_CHANNEL` IS NULL),
    named_struct('Column_Name','SCON_ANNIVERSARY_DT','is_null', `SCON_ANNIVERSARY_DT` IS NULL),
    named_struct('Column_Name','SCON_COMMERCIAL_FLAG','is_null', `SCON_COMMERCIAL_FLAG` IS NULL),
    named_struct('Column_Name','SCON_EMAILRECEIPT_FLAG','is_null', `SCON_EMAILRECEIPT_FLAG` IS NULL),
    named_struct('Column_Name','SCON_PROSPECT_FLAG','is_null', `SCON_PROSPECT_FLAG` IS NULL),
    named_struct('Column_Name','SCON_ACTIVE_FLAG','is_null', `SCON_ACTIVE_FLAG` IS NULL),
    named_struct('Column_Name','SCON_HRREQUESTTIMESTAMP','is_null', `SCON_HRREQUESTTIMESTAMP` IS NULL),
    named_struct('Column_Name','SCON_STATUS','is_null', `SCON_STATUS` IS NULL),
    named_struct('Column_Name','SCON_CREATION_DT','is_null', `SCON_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCON_CREATION_UID','is_null', `SCON_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCON_UPDATE_DT','is_null', `SCON_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCON_UPDATE_UID','is_null', `SCON_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCON_CBR_FLAG','is_null', `SCON_CBR_FLAG` IS NULL),
    named_struct('Column_Name','SCON_FIRSTPURCHASEDATE','is_null', `SCON_FIRSTPURCHASEDATE` IS NULL),
    named_struct('Column_Name','SCON_DELETE_FLAG','is_null', `SCON_DELETE_FLAG` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHNAME_QUALITY_CODE','is_null', `SCON_ENGLISHNAME_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCON_LOCALNAME_QUALITY_CODE','is_null', `SCON_LOCALNAME_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCON_LOCALNAME2_QUALITY_CODE','is_null', `SCON_LOCALNAME2_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCON_UNIVERSALKEY','is_null', `SCON_UNIVERSALKEY` IS NULL),
    named_struct('Column_Name','SCON_MASTERCONSUMERID','is_null', `SCON_MASTERCONSUMERID` IS NULL),
    named_struct('Column_Name','SCON_SOURCESYSTEMCODE','is_null', `SCON_SOURCESYSTEMCODE` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)

SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

select
    count(*)
from
    ${databricks_database}.t_master_consumer
where
    where SCON_MRKT_CODE not in ('SGP', 'TWN')
-- left join
--     ${databricks_database}.t_master_phone

# %%
get_talend_df(talend_snapshot_path, "sconsumer").createOrReplaceGlobalTempView("sconsumer")

# %%
# %sql

select count(*) from global_temp.sconsumer

# %%
# %sql

WITH talend_base AS

(
select
  base_tab.*
from  
  global_temp.sconsumer as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),

kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCON_ID','is_null', `SCON_ID` IS NULL),
    named_struct('Column_Name','SCON_SRCC_ID','is_null', `SCON_SRCC_ID` IS NULL),
    named_struct('Column_Name','SCON_SRCC_ACTION','is_null', `SCON_SRCC_ACTION` IS NULL),
    named_struct('Column_Name','CONSUMERMDMKEY','is_null', `CONSUMERMDMKEY` IS NULL),
    named_struct('Column_Name','SCON_SRCS_CODE','is_null', `SCON_SRCS_CODE` IS NULL),
    named_struct('Column_Name','SCON_SOURCETIMESTAMP','is_null', `SCON_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCON_MRKT_CODE','is_null', `SCON_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCON_AFF_CODE','is_null', `SCON_AFF_CODE` IS NULL),
    named_struct('Column_Name','SCON_DVSN_CODE','is_null', `SCON_DVSN_CODE` IS NULL),
    named_struct('Column_Name','SCON_BRND_CODE','is_null', `SCON_BRND_CODE` IS NULL),
    named_struct('Column_Name','SCON_CONSUMERID','is_null', `SCON_CONSUMERID` IS NULL),
    named_struct('Column_Name','SCON_SALUTATION','is_null', `SCON_SALUTATION` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHFIRSTNAME','is_null', `SCON_ENGLISHFIRSTNAME` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHMIDDLENAME','is_null', `SCON_ENGLISHMIDDLENAME` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHLASTNAME','is_null', `SCON_ENGLISHLASTNAME` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHFULLNAME','is_null', `SCON_ENGLISHFULLNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALFIRSTNAME','is_null', `SCON_LOCALFIRSTNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALMIDDLENAME','is_null', `SCON_LOCALMIDDLENAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALLASTNAME','is_null', `SCON_LOCALLASTNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALFULLNAME','is_null', `SCON_LOCALFULLNAME` IS NULL),
    named_struct('Column_Name','SCON_LOCALFIRSTNAME2','is_null', `SCON_LOCALFIRSTNAME2` IS NULL),
    named_struct('Column_Name','SCON_LOCALMIDDLENAME2','is_null', `SCON_LOCALMIDDLENAME2` IS NULL),
    named_struct('Column_Name','SCON_LOCALLASTNAME2','is_null', `SCON_LOCALLASTNAME2` IS NULL),
    named_struct('Column_Name','SCON_LOCALFULLNAME2','is_null', `SCON_LOCALFULLNAME2` IS NULL),
    named_struct('Column_Name','SCON_GNDR_CODE','is_null', `SCON_GNDR_CODE` IS NULL),
    named_struct('Column_Name','SCON_BIRTHDAY','is_null', `SCON_BIRTHDAY` IS NULL),
    named_struct('Column_Name','SCON_BIRTHMONTH','is_null', `SCON_BIRTHMONTH` IS NULL),
    named_struct('Column_Name','SCON_BIRTHYEAR','is_null', `SCON_BIRTHYEAR` IS NULL),
    named_struct('Column_Name','SCON_IDENTITYNUM','is_null', `SCON_IDENTITYNUM` IS NULL),
    named_struct('Column_Name','SCON_PASSPORTNUM','is_null', `SCON_PASSPORTNUM` IS NULL),
    named_struct('Column_Name','SCON_SOCIALSECURITYNUM','is_null', `SCON_SOCIALSECURITYNUM` IS NULL),
    named_struct('Column_Name','SCON_CLAS_CODE','is_null', `SCON_CLAS_CODE` IS NULL),
    named_struct('Column_Name','SCON_REG_DT','is_null', `SCON_REG_DT` IS NULL),
    named_struct('Column_Name','SCON_REGISTRATION_TOCH_CODE','is_null', `SCON_REGISTRATION_TOCH_CODE` IS NULL),
    named_struct('Column_Name','SCON_REGISTRATION_PRSN_CODE','is_null', `SCON_REGISTRATION_PRSN_CODE` IS NULL),
    named_struct('Column_Name','SCON_PREFERRED_TOCH_CODE','is_null', `SCON_PREFERRED_TOCH_CODE` IS NULL),
    named_struct('Column_Name','SCON_ASSIGNED_PRSN_CODE','is_null', `SCON_ASSIGNED_PRSN_CODE` IS NULL),
    named_struct('Column_Name','SCON_WLNG_CODE','is_null', `SCON_WLNG_CODE` IS NULL),
    named_struct('Column_Name','SCON_SLNG_CODE','is_null', `SCON_SLNG_CODE` IS NULL),
    named_struct('Column_Name','SCON_CNTR_ISOALPHA3CODE','is_null', `SCON_CNTR_ISOALPHA3CODE` IS NULL),
    named_struct('Column_Name','SCON_ETHN_CODE','is_null', `SCON_ETHN_CODE` IS NULL),
    named_struct('Column_Name','SCON_SKNT_CODE','is_null', `SCON_SKNT_CODE` IS NULL),
    named_struct('Column_Name','SCON_HAIRT_CODE','is_null', `SCON_HAIRT_CODE` IS NULL),
    named_struct('Column_Name','SCON_CVLS_CODE','is_null', `SCON_CVLS_CODE` IS NULL),
    named_struct('Column_Name','SCON_COMPANY','is_null', `SCON_COMPANY` IS NULL),
    named_struct('Column_Name','SCON_DEPARTMENT','is_null', `SCON_DEPARTMENT` IS NULL),
    named_struct('Column_Name','SCON_JOBTITLE','is_null', `SCON_JOBTITLE` IS NULL),
    named_struct('Column_Name','SCON_YEARLYINCOME','is_null', `SCON_YEARLYINCOME` IS NULL),
    named_struct('Column_Name','SCON_DONOTCONTACT_FLAG','is_null', `SCON_DONOTCONTACT_FLAG` IS NULL),
    named_struct('Column_Name','SCON_CURR_CODE','is_null', `SCON_CURR_CODE` IS NULL),
    named_struct('Column_Name','SCON_AGEFROM','is_null', `SCON_AGEFROM` IS NULL),
    named_struct('Column_Name','SCON_AGETO','is_null', `SCON_AGETO` IS NULL),
    named_struct('Column_Name','SCON_NATIONALITY','is_null', `SCON_NATIONALITY` IS NULL),
    named_struct('Column_Name','SCON_CHANNEL','is_null', `SCON_CHANNEL` IS NULL),
    named_struct('Column_Name','SCON_PREFERRED_COMM_CHANNEL','is_null', `SCON_PREFERRED_COMM_CHANNEL` IS NULL),
    named_struct('Column_Name','SCON_ANNIVERSARY_DT','is_null', `SCON_ANNIVERSARY_DT` IS NULL),
    named_struct('Column_Name','SCON_COMMERCIAL_FLAG','is_null', `SCON_COMMERCIAL_FLAG` IS NULL),
    named_struct('Column_Name','SCON_EMAILRECEIPT_FLAG','is_null', `SCON_EMAILRECEIPT_FLAG` IS NULL),
    named_struct('Column_Name','SCON_PROSPECT_FLAG','is_null', `SCON_PROSPECT_FLAG` IS NULL),
    named_struct('Column_Name','SCON_ACTIVE_FLAG','is_null', `SCON_ACTIVE_FLAG` IS NULL),
    named_struct('Column_Name','SCON_HRREQUESTTIMESTAMP','is_null', `SCON_HRREQUESTTIMESTAMP` IS NULL),
    named_struct('Column_Name','SCON_STATUS','is_null', `SCON_STATUS` IS NULL),
    named_struct('Column_Name','SCON_CREATION_DT','is_null', `SCON_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCON_CREATION_UID','is_null', `SCON_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCON_UPDATE_DT','is_null', `SCON_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCON_UPDATE_UID','is_null', `SCON_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCON_CBR_FLAG','is_null', `SCON_CBR_FLAG` IS NULL),
    named_struct('Column_Name','SCON_FIRSTPURCHASEDATE','is_null', `SCON_FIRSTPURCHASEDATE` IS NULL),
    named_struct('Column_Name','SCON_DELETE_FLAG','is_null', `SCON_DELETE_FLAG` IS NULL),
    named_struct('Column_Name','SCON_ENGLISHNAME_QUALITY_CODE','is_null', `SCON_ENGLISHNAME_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCON_LOCALNAME_QUALITY_CODE','is_null', `SCON_LOCALNAME_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCON_LOCALNAME2_QUALITY_CODE','is_null', `SCON_LOCALNAME2_QUALITY_CODE` IS NULL)
    -- ,
    -- named_struct('Column_Name','SCON_UNIVERSALKEY','is_null', `SCON_UNIVERSALKEY` IS NULL),
    -- named_struct('Column_Name','SCON_MASTERCONSUMERID','is_null', `SCON_MASTERCONSUMERID` IS NULL),
    -- named_struct('Column_Name','SCON_SOURCESYSTEMCODE','is_null', `SCON_SOURCESYSTEMCODE` IS NULL),
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * from ${databricks_database}.t_master_emedia where SCME_MRKT_CODE not in ('SGP', 'TWN'))
  
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCME_ID','is_null', `SCME_ID` IS NULL),
    named_struct('Column_Name','SCME_SCON_ID','is_null', `SCME_SCON_ID` IS NULL),
    named_struct('Column_Name','SCME_MRKT_CODE','is_null', `SCME_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCME_EMDT_CODE','is_null', `SCME_EMDT_CODE` IS NULL),
    named_struct('Column_Name','SCME_SOURCETIMESTAMP','is_null', `SCME_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCME_ADDRESS','is_null', `SCME_ADDRESS` IS NULL),
    named_struct('Column_Name','SCME_VALIDITYCODE','is_null', `SCME_VALIDITYCODE` IS NULL),
    named_struct('Column_Name','SCME_PRIMARY_FLAG','is_null', `SCME_PRIMARY_FLAG` IS NULL),
    named_struct('Column_Name','SCME_APPID','is_null', `SCME_APPID` IS NULL),
    named_struct('Column_Name','SCME_CONTACTOPTINFLAG','is_null', `SCME_CONTACTOPTINFLAG` IS NULL),
    named_struct('Column_Name','SCME_REFERENCEEMEDIATYPECODE','is_null', `SCME_REFERENCEEMEDIATYPECODE` IS NULL),
    named_struct('Column_Name','SCME_REFERENCEEMEDIAADDRESS','is_null', `SCME_REFERENCEEMEDIAADDRESS` IS NULL),
    named_struct('Column_Name','SCME_QUALITY_CODE','is_null', `SCME_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCME_QUALITY_DESC','is_null', `SCME_QUALITY_DESC` IS NULL),
    named_struct('Column_Name','SCME_CREATION_DT','is_null', `SCME_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCME_CREATION_UID','is_null', `SCME_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCME_UPDATE_DT','is_null', `SCME_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCME_UPDATE_UID','is_null', `SCME_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCME_UPDATE_FLAG','is_null', `SCME_UPDATE_FLAG` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# all_talend_emedia_consumer_sql = f"""
# (
#     select  'aus_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'hkg_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'idn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumermedia` 
#     union all  
#     select  'jpn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'kor_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'mys_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'nzl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'phl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'sgp_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'tha_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'twn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumermedia` 
#     union all
#     select  'vnm_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumermedia` 
# )
# """

# spark.sql(all_talend_emedia_consumer_sql).createOrReplaceGlobalTempView("all_talend_emedia_consumer_tab")

get_talend_df(talend_snapshot_path, "sconsumermedia").createOrReplaceGlobalTempView("all_talend_emedia_consumer_tab")

# %%
# %sql

WITH talend_base AS
(select
  distinct base_tab.*
from  
  global_temp.all_talend_emedia_consumer_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scme_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),

kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCME_ID','is_null', `SCME_ID` IS NULL),
    named_struct('Column_Name','SCME_SCON_ID','is_null', `SCME_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCME_MRKT_CODE','is_null', `SCME_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCME_EMDT_CODE','is_null', `SCME_EMDT_CODE` IS NULL),
    named_struct('Column_Name','SCME_SOURCETIMESTAMP','is_null', `SCME_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCME_ADDRESS','is_null', `SCME_ADDRESS` IS NULL),
    named_struct('Column_Name','SCME_VALIDITYCODE','is_null', `SCME_VALIDITYCODE` IS NULL),
    named_struct('Column_Name','SCME_PRIMARY_FLAG','is_null', `SCME_PRIMARY_FLAG` IS NULL),
    named_struct('Column_Name','SCME_APPID','is_null', `SCME_APPID` IS NULL),
    named_struct('Column_Name','SCME_CONTACTOPTINFLAG','is_null', `SCME_CONTACTOPTINFLAG` IS NULL),
    named_struct('Column_Name','SCME_REFERENCEEMEDIATYPECODE','is_null', `SCME_REFERENCEEMEDIATYPECODE` IS NULL),
    named_struct('Column_Name','SCME_REFERENCEEMEDIAADDRESS','is_null', `SCME_REFERENCEEMEDIAADDRESS` IS NULL),
    named_struct('Column_Name','SCME_QUALITY_CODE','is_null', `SCME_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCME_QUALITY_DESC','is_null', `SCME_QUALITY_DESC` IS NULL),
    named_struct('Column_Name','SCME_CREATION_DT','is_null', `SCME_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCME_CREATION_UID','is_null', `SCME_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCME_UPDATE_DT','is_null', `SCME_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCME_UPDATE_UID','is_null', `SCME_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCME_UPDATE_FLAG','is_null', `SCME_UPDATE_FLAG` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH talend_base AS
(select
  distinct base_tab.*
from  
  global_temp.all_talend_emedia_consumer_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scme_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

select count(*) from talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * from ${databricks_database}.t_master_phone WHERE SCPH_MRKT_CODE not in ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCPH_ID','is_null', `SCPH_ID` IS NULL),
    named_struct('Column_Name','SCPH_SCON_ID','is_null', `SCPH_SCON_ID` IS NULL),
    named_struct('Column_Name','SCPH_MRKT_CODE','is_null', `SCPH_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCPH_PHNT_CODE','is_null', `SCPH_PHNT_CODE` IS NULL),
    named_struct('Column_Name','SCPH_SOURCETIMESTAMP','is_null', `SCPH_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCPH_PHONECOUNTRYCODE','is_null', `SCPH_PHONECOUNTRYCODE` IS NULL),
    named_struct('Column_Name','SCPH_PHONENUMBER','is_null', `SCPH_PHONENUMBER` IS NULL),
    named_struct('Column_Name','SCPH_VALIDITYCODE','is_null', `SCPH_VALIDITYCODE` IS NULL),
    named_struct('Column_Name','SCPH_PRIMARY_FLAG','is_null', `SCPH_PRIMARY_FLAG` IS NULL),
    named_struct('Column_Name','SCPH_QUALITY_CODE','is_null', `SCPH_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCPH_QUALITY_DESC','is_null', `SCPH_QUALITY_DESC` IS NULL),
    named_struct('Column_Name','SCPH_CREATION_DT','is_null', `SCPH_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCPH_CREATION_UID','is_null', `SCPH_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCPH_UPDATE_DT','is_null', `SCPH_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCPH_UPDATE_UID','is_null', `SCPH_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCPH_UPDATE_FLAG','is_null', `SCPH_UPDATE_FLAG` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# all_talend_phone_consumer_sql = f"""
# (
# select  'aus_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumerphone` 
#  union all
# select  'hkg_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumerphone` 
#  union all
# select  'idn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumerphone` 
#  union all  
# select  'jpn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumerphone` 
#  union all
# select  'kor_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumerphone` 
#  union all
# select  'mys_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumerphone` 
#  union all
# select  'nzl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumerphone` 
#  union all
# select  'phl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumerphone` 
#  union all
# select  'sgp_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumerphone` 
#  union all
# select  'tha_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumerphone` 
#  union all
# select  'twn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumerphone` 
# union all
# select  'vnm_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumerphone` 
# )
# """

# spark.sql(all_talend_phone_consumer_sql).createOrReplaceGlobalTempView("all_talend_phone_consumer_tab")

get_talend_df(talend_snapshot_path, "sconsumerphone").createOrReplaceGlobalTempView("all_talend_phone_consumer_tab")

# %%
# %sql

WITH talend_base AS
(select
  base_tab.*
from  
  global_temp.all_talend_phone_consumer_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCPH_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCPH_ID','is_null', `SCPH_ID` IS NULL),
    named_struct('Column_Name','SCPH_SCON_ID','is_null', `SCPH_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCPH_MRKT_CODE','is_null', `SCPH_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCPH_PHNT_CODE','is_null', `SCPH_PHNT_CODE` IS NULL),
    named_struct('Column_Name','SCPH_SOURCETIMESTAMP','is_null', `SCPH_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCPH_PHONECOUNTRYCODE','is_null', `SCPH_PHONECOUNTRYCODE` IS NULL),
    named_struct('Column_Name','SCPH_PHONENUMBER','is_null', `SCPH_PHONENUMBER` IS NULL),
    named_struct('Column_Name','SCPH_VALIDITYCODE','is_null', `SCPH_VALIDITYCODE` IS NULL),
    named_struct('Column_Name','SCPH_PRIMARY_FLAG','is_null', `SCPH_PRIMARY_FLAG` IS NULL),
    named_struct('Column_Name','SCPH_QUALITY_CODE','is_null', `SCPH_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCPH_QUALITY_DESC','is_null', `SCPH_QUALITY_DESC` IS NULL),
    named_struct('Column_Name','SCPH_CREATION_DT','is_null', `SCPH_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCPH_CREATION_UID','is_null', `SCPH_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCPH_UPDATE_DT','is_null', `SCPH_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCPH_UPDATE_UID','is_null', `SCPH_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCPH_UPDATE_FLAG','is_null', `SCPH_UPDATE_FLAG` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH talend_base AS
(select
  base_tab.*
from  
  global_temp.all_talend_phone_consumer_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCPH_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * from ${databricks_database}.t_master_address where SCAD_MRKT_CODE not in ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCAD_ID','is_null', `SCAD_ID` IS NULL),
    named_struct('Column_Name','SCAD_SCON_ID','is_null', `SCAD_SCON_ID` IS NULL),
    named_struct('Column_Name','SCAD_MRKT_CODE','is_null', `SCAD_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCAD_ADDT_CODE','is_null', `SCAD_ADDT_CODE` IS NULL),
    named_struct('Column_Name','SCAD_SOURCETIMESTAMP','is_null', `SCAD_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCAD_ADDRESS1','is_null', `SCAD_ADDRESS1` IS NULL),
    named_struct('Column_Name','SCAD_ADDRESS2','is_null', `SCAD_ADDRESS2` IS NULL),
    named_struct('Column_Name','SCAD_ADDRESS3','is_null', `SCAD_ADDRESS3` IS NULL),
    named_struct('Column_Name','SCAD_CITY_LOCALDESC','is_null', `SCAD_CITY_LOCALDESC` IS NULL),
    named_struct('Column_Name','SCAD_PRVN_LOCALDESC','is_null', `SCAD_PRVN_LOCALDESC` IS NULL),
    named_struct('Column_Name','SCAD_CNTR_ISOALPHA3CODE','is_null', `SCAD_CNTR_ISOALPHA3CODE` IS NULL),
    named_struct('Column_Name','SCAD_POSTALCODE','is_null', `SCAD_POSTALCODE` IS NULL),
    named_struct('Column_Name','SCAD_VALIDITYCODE','is_null', `SCAD_VALIDITYCODE` IS NULL),
    named_struct('Column_Name','SCAD_PRIMARY_FLAG','is_null', `SCAD_PRIMARY_FLAG` IS NULL),
    named_struct('Column_Name','SCAD_QUALITY_CODE','is_null', `SCAD_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCAD_QUALITY_DESC','is_null', `SCAD_QUALITY_DESC` IS NULL),
    named_struct('Column_Name','SCAD_CREATION_DT','is_null', `SCAD_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCAD_CREATION_UID','is_null', `SCAD_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCAD_UPDATE_DT','is_null', `SCAD_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCAD_UPDATE_UID','is_null', `SCAD_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCAD_UPDATE_FLAG','is_null', `SCAD_UPDATE_FLAG` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# address_all_talend_sql = f"""
# (
# select  'aus_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'hkg_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'idn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumeraddress` 
#  union all  
# select  'jpn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'kor_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'mys_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'nzl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'phl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'sgp_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'tha_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumeraddress` 
#  union all
# select  'twn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumeraddress` 
# union all
# select  'vnm_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumeraddress` 
# )
# """

# spark.sql(address_all_talend_sql).createOrReplaceGlobalTempView("address_all_talend_tab")
get_talend_df(talend_snapshot_path, "sconsumeraddress").createOrReplaceGlobalTempView("address_all_talend_tab")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.address_all_talend_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scad_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCAD_ID','is_null', `SCAD_ID` IS NULL),
    named_struct('Column_Name','SCAD_SCON_ID','is_null', `SCAD_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCAD_MRKT_CODE','is_null', `SCAD_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCAD_ADDT_CODE','is_null', `SCAD_ADDT_CODE` IS NULL),
    named_struct('Column_Name','SCAD_SOURCETIMESTAMP','is_null', `SCAD_SOURCETIMESTAMP` IS NULL),
    named_struct('Column_Name','SCAD_ADDRESS1','is_null', `SCAD_ADDRESS1` IS NULL),
    named_struct('Column_Name','SCAD_ADDRESS2','is_null', `SCAD_ADDRESS2` IS NULL),
    named_struct('Column_Name','SCAD_ADDRESS3','is_null', `SCAD_ADDRESS3` IS NULL),
    named_struct('Column_Name','SCAD_CITY_LOCALDESC','is_null', `SCAD_CITY_LOCALDESC` IS NULL),
    named_struct('Column_Name','SCAD_PRVN_LOCALDESC','is_null', `SCAD_PRVN_LOCALDESC` IS NULL),
    named_struct('Column_Name','SCAD_CNTR_ISOALPHA3CODE','is_null', `SCAD_CNTR_ISOALPHA3CODE` IS NULL),
    named_struct('Column_Name','SCAD_POSTALCODE','is_null', `SCAD_POSTALCODE` IS NULL),
    named_struct('Column_Name','SCAD_VALIDITYCODE','is_null', `SCAD_VALIDITYCODE` IS NULL),
    named_struct('Column_Name','SCAD_PRIMARY_FLAG','is_null', `SCAD_PRIMARY_FLAG` IS NULL),
    named_struct('Column_Name','SCAD_QUALITY_CODE','is_null', `SCAD_QUALITY_CODE` IS NULL),
    named_struct('Column_Name','SCAD_QUALITY_DESC','is_null', `SCAD_QUALITY_DESC` IS NULL),
    named_struct('Column_Name','SCAD_CREATION_DT','is_null', `SCAD_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCAD_CREATION_UID','is_null', `SCAD_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCAD_UPDATE_DT','is_null', `SCAD_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCAD_UPDATE_UID','is_null', `SCAD_UPDATE_UID` IS NULL),
    named_struct('Column_Name','SCAD_UPDATE_FLAG','is_null', `SCAD_UPDATE_FLAG` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.address_all_talend_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scad_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)


SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_optin where SCOP_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCOP_ID','is_null', `SCOP_ID` IS NULL),
    named_struct('Column_Name','SCOP_SCON_ID','is_null', `SCOP_SCON_ID` IS NULL),
    named_struct('Column_Name','SCOP_MRKT_CODE','is_null', `SCOP_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCOP_OPTIN_DT','is_null', `SCOP_OPTIN_DT` IS NULL),
    named_struct('Column_Name','SCOP_COMM_CODE','is_null', `SCOP_COMM_CODE` IS NULL),
    named_struct('Column_Name','SCOP_OPTIN_FLAG','is_null', `SCOP_OPTIN_FLAG` IS NULL),
    named_struct('Column_Name','SCOP_CREATION_DT','is_null', `SCOP_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCOP_CREATION_UID','is_null', `SCOP_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCOP_UPDATE_DT','is_null', `SCOP_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCOP_UPDATE_UID','is_null', `SCOP_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# optin_all_talend_sql = f"""
# (
# select  'aus_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'hkg_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'idn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumeroptin` 
#  union all  
# select  'jpn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'kor_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'mys_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'nzl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'phl_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'sgp_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'tha_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumeroptin` 
#  union all
# select  'twn_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumeroptin` 
# union all
# select  'vnm_elcconsumermdm' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumeroptin` 
# )
# """

# spark.sql(optin_all_talend_sql).createOrReplaceGlobalTempView("option_all_talend_tab")
get_talend_df(talend_snapshot_path, "sconsumeroptin").createOrReplaceGlobalTempView("option_all_talend_tab")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.option_all_talend_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scop_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
     named_struct('Column_Name','SCOP_ID','is_null', `SCOP_ID` IS NULL),
    named_struct('Column_Name','SCOP_SCON_ID','is_null', `SCOP_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCOP_MRKT_CODE','is_null', `SCOP_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCOP_OPTIN_DT','is_null', `SCOP_OPTIN_DT` IS NULL),
    named_struct('Column_Name','SCOP_COMM_CODE','is_null', `SCOP_COMM_CODE` IS NULL),
    named_struct('Column_Name','SCOP_OPTIN_FLAG','is_null', `SCOP_OPTIN_FLAG` IS NULL),
    named_struct('Column_Name','SCOP_CREATION_DT','is_null', `SCOP_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCOP_CREATION_UID','is_null', `SCOP_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCOP_UPDATE_DT','is_null', `SCOP_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCOP_UPDATE_UID','is_null', `SCOP_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.option_all_talend_tab as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scop_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_crossbrand_optin WHERE SCBO_MRKT_CODE not in ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCBO_ID','is_null', `SCBO_ID` IS NULL),
    named_struct('Column_Name','SCBO_SCON_ID','is_null', `SCBO_SCON_ID` IS NULL),
    named_struct('Column_Name','SCBO_MRKT_CODE','is_null', `SCBO_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCBO_OPTIN_DT','is_null', `SCBO_OPTIN_DT` IS NULL),
    named_struct('Column_Name','SCBO_OPTIN_FLAG','is_null', `SCBO_OPTIN_FLAG` IS NULL),
    named_struct('Column_Name','SCBO_CREATION_DT','is_null', `SCBO_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCBO_CREATION_UID','is_null', `SCBO_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCBO_UPDATE_DT','is_null', `SCBO_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCBO_UPDATE_UID','is_null', `SCBO_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumercrossbrandoptin").createOrReplaceGlobalTempView("sconsumercrossbrandoptin")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumercrossbrandoptin as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCBO_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCBO_ID','is_null', `SCBO_ID` IS NULL),
    named_struct('Column_Name','SCBO_SCON_ID','is_null', `SCBO_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCBO_MRKT_CODE','is_null', `SCBO_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCBO_OPTIN_DT','is_null', `SCBO_OPTIN_DT` IS NULL),
    named_struct('Column_Name','SCBO_OPTIN_FLAG','is_null', `SCBO_OPTIN_FLAG` IS NULL),
    named_struct('Column_Name','SCBO_CREATION_DT','is_null', `SCBO_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCBO_CREATION_UID','is_null', `SCBO_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCBO_UPDATE_DT','is_null', `SCBO_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCBO_UPDATE_UID','is_null', `SCBO_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumercrossbrandoptin as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCBO_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_program WHERE SCPR_MRKT_CODE not in ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCPR_ID','is_null', `SCPR_ID` IS NULL),
    named_struct('Column_Name','SCPR_SCON_ID','is_null', `SCPR_SCON_ID` IS NULL),
    named_struct('Column_Name','SCPR_MRKT_CODE','is_null', `SCPR_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCPR_APPLICATION_TOCH_CODE','is_null', `SCPR_APPLICATION_TOCH_CODE` IS NULL),
    named_struct('Column_Name','SCPR_CONSUMER_GRP','is_null', `SCPR_CONSUMER_GRP` IS NULL),
    named_struct('Column_Name','SCPR_PRGT_CODE','is_null', `SCPR_PRGT_CODE` IS NULL),
    named_struct('Column_Name','SCPR_PRGT_DESC','is_null', `SCPR_PRGT_DESC` IS NULL),
    named_struct('Column_Name','SCPR_PRGL_CODE','is_null', `SCPR_PRGL_CODE` IS NULL),
    named_struct('Column_Name','SCPR_PRGL_DESC','is_null', `SCPR_PRGL_DESC` IS NULL),
    named_struct('Column_Name','SCPR_SYSTEM_CODE','is_null', `SCPR_SYSTEM_CODE` IS NULL),
    named_struct('Column_Name','SCPR_SYSTEM_DESC','is_null', `SCPR_SYSTEM_DESC` IS NULL),
    named_struct('Column_Name','SCPR_MEMBERSHIPNUM','is_null', `SCPR_MEMBERSHIPNUM` IS NULL),
    named_struct('Column_Name','SCPR_CARDNUM','is_null', `SCPR_CARDNUM` IS NULL),
    named_struct('Column_Name','SCPR_START_DT','is_null', `SCPR_START_DT` IS NULL),
    named_struct('Column_Name','SCPR_END_DT','is_null', `SCPR_END_DT` IS NULL),
    named_struct('Column_Name','SCPR_ACQUIREDPOINT_NUM','is_null', `SCPR_ACQUIREDPOINT_NUM` IS NULL),
    named_struct('Column_Name','SCPR_REDEEMEDPOINT_NUM','is_null', `SCPR_REDEEMEDPOINT_NUM` IS NULL),
    named_struct('Column_Name','SCPR_INITIAL_QUOTA','is_null', `SCPR_INITIAL_QUOTA` IS NULL),
    named_struct('Column_Name','SCPR_AVAILABLE_QUOTA','is_null', `SCPR_AVAILABLE_QUOTA` IS NULL),
    named_struct('Column_Name','SCPR_CREATION_DT','is_null', `SCPR_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCPR_CREATION_UID','is_null', `SCPR_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCPR_UPDATE_DT','is_null', `SCPR_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCPR_UPDATE_UID','is_null', `SCPR_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerprogram").createOrReplaceGlobalTempView("sconsumerprogram")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerprogram as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scpr_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCPR_ID','is_null', `SCPR_ID` IS NULL),
    named_struct('Column_Name','SCPR_SCON_ID','is_null', `SCPR_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCPR_MRKT_CODE','is_null', `SCPR_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCPR_APPLICATION_TOCH_CODE','is_null', `SCPR_APPLICATION_TOCH_CODE` IS NULL),
    named_struct('Column_Name','SCPR_CONSUMER_GRP','is_null', `SCPR_CONSUMER_GRP` IS NULL),
    named_struct('Column_Name','SCPR_PRGT_CODE','is_null', `SCPR_PRGT_CODE` IS NULL),
    named_struct('Column_Name','SCPR_PRGT_DESC','is_null', `SCPR_PRGT_DESC` IS NULL),
    named_struct('Column_Name','SCPR_PRGL_CODE','is_null', `SCPR_PRGL_CODE` IS NULL),
    named_struct('Column_Name','SCPR_PRGL_DESC','is_null', `SCPR_PRGL_DESC` IS NULL),
    named_struct('Column_Name','SCPR_SYSTEM_CODE','is_null', `SCPR_SYSTEM_CODE` IS NULL),
    named_struct('Column_Name','SCPR_SYSTEM_DESC','is_null', `SCPR_SYSTEM_DESC` IS NULL),
    named_struct('Column_Name','SCPR_MEMBERSHIPNUM','is_null', `SCPR_MEMBERSHIPNUM` IS NULL),
    named_struct('Column_Name','SCPR_CARDNUM','is_null', `SCPR_CARDNUM` IS NULL),
    named_struct('Column_Name','SCPR_START_DT','is_null', `SCPR_START_DT` IS NULL),
    named_struct('Column_Name','SCPR_END_DT','is_null', `SCPR_END_DT` IS NULL),
    named_struct('Column_Name','SCPR_ACQUIREDPOINT_NUM','is_null', `SCPR_ACQUIREDPOINT_NUM` IS NULL),
    named_struct('Column_Name','SCPR_REDEEMEDPOINT_NUM','is_null', `SCPR_REDEEMEDPOINT_NUM` IS NULL),
    named_struct('Column_Name','SCPR_INITIAL_QUOTA','is_null', `SCPR_INITIAL_QUOTA` IS NULL),
    named_struct('Column_Name','SCPR_AVAILABLE_QUOTA','is_null', `SCPR_AVAILABLE_QUOTA` IS NULL),
    named_struct('Column_Name','SCPR_CREATION_DT','is_null', `SCPR_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCPR_CREATION_UID','is_null', `SCPR_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCPR_UPDATE_DT','is_null', `SCPR_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCPR_UPDATE_UID','is_null', `SCPR_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerprogram as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.scpr_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
get_talend_df(talend_snapshot_path, "sconsumerauxiliaryattribute").createOrReplaceGlobalTempView("sconsumerauxiliaryattribute")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerauxiliaryattribute as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCAA_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCAA_ID','is_null', `SCAA_ID` IS NULL),
    named_struct('Column_Name','SCAA_SCON_ID','is_null', `SCAA_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCAA_MRKT_CODE','is_null', `SCAA_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCAA_CODE','is_null', `SCAA_CODE` IS NULL),
    named_struct('Column_Name','SCAA_DESC','is_null', `SCAA_DESC` IS NULL),
    named_struct('Column_Name','SCAA_MULTIVALUEFLAG','is_null', `SCAA_MULTIVALUEFLAG` IS NULL),
    named_struct('Column_Name','SCAA_VALUE','is_null', `SCAA_VALUE` IS NULL),
    named_struct('Column_Name','SCAA_ACTIVE_FLAG','is_null', `SCAA_ACTIVE_FLAG` IS NULL),
    named_struct('Column_Name','SCAA_CREATION_DT','is_null', `SCAA_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCAA_CREATION_UID','is_null', `SCAA_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCAA_UPDATE_DT','is_null', `SCAA_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCAA_UPDATE_UID','is_null', `SCAA_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerauxiliaryattribute as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCAA_scon_id = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_auxiliary_attribute WHERE SCAA_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCAA_ID','is_null', `SCAA_ID` IS NULL),
    named_struct('Column_Name','SCAA_SCON_ID','is_null', `SCAA_SCON_ID` IS NULL),
    named_struct('Column_Name','SCAA_MRKT_CODE','is_null', `SCAA_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCAA_CODE','is_null', `SCAA_CODE` IS NULL),
    named_struct('Column_Name','SCAA_DESC','is_null', `SCAA_DESC` IS NULL),
    named_struct('Column_Name','SCAA_MULTIVALUEFLAG','is_null', `SCAA_MULTIVALUEFLAG` IS NULL),
    named_struct('Column_Name','SCAA_VALUE','is_null', `SCAA_VALUE` IS NULL),
    named_struct('Column_Name','SCAA_ACTIVE_FLAG','is_null', `SCAA_ACTIVE_FLAG` IS NULL),
    named_struct('Column_Name','SCAA_CREATION_DT','is_null', `SCAA_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCAA_CREATION_UID','is_null', `SCAA_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCAA_UPDATE_DT','is_null', `SCAA_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCAA_UPDATE_UID','is_null', `SCAA_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerauxiliaryattribute").createOrReplaceGlobalTempView("sconsumerauxiliaryattribute")

# %%
# %sql
select * from global_temp.sconsumerauxiliaryattribute

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerauxiliaryattribute as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCAA_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),

kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM talend_base
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCAA_ID','is_null', `SCAA_ID` IS NULL),
    named_struct('Column_Name','SCAA_SCON_ID','is_null', `SCAA_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCAA_MRKT_CODE','is_null', `SCAA_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCAA_CODE','is_null', `SCAA_CODE` IS NULL),
    named_struct('Column_Name','SCAA_DESC','is_null', `SCAA_DESC` IS NULL),
    named_struct('Column_Name','SCAA_MULTIVALUEFLAG','is_null', `SCAA_MULTIVALUEFLAG` IS NULL),
    named_struct('Column_Name','SCAA_VALUE','is_null', `SCAA_VALUE` IS NULL),
    named_struct('Column_Name','SCAA_ACTIVE_FLAG','is_null', `SCAA_ACTIVE_FLAG` IS NULL),
    named_struct('Column_Name','SCAA_CREATION_DT','is_null', `SCAA_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCAA_CREATION_UID','is_null', `SCAA_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCAA_UPDATE_DT','is_null', `SCAA_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCAA_UPDATE_UID','is_null', `SCAA_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_custom_attributes WHERE SCCU_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCCU_ID','is_null', `SCCU_ID` IS NULL),
    named_struct('Column_Name','SCCU_SCON_ID','is_null', `SCCU_SCON_ID` IS NULL),
    named_struct('Column_Name','SCCU_MRKT_CODE','is_null', `SCCU_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCCU_NAME','is_null', `SCCU_NAME` IS NULL),
    named_struct('Column_Name','SCCU_VALUE','is_null', `SCCU_VALUE` IS NULL),
    named_struct('Column_Name','SCCU_CREATION_DT','is_null', `SCCU_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCCU_CREATION_UID','is_null', `SCCU_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCCU_UPDATE_DT','is_null', `SCCU_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCCU_UPDATE_UID','is_null', `SCCU_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumercustomattr").createOrReplaceGlobalTempView("sconsumercustomattr")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumercustomattr as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCCU_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCCU_ID','is_null', `SCCU_ID` IS NULL),
    named_struct('Column_Name','SCCU_SCON_ID','is_null', `SCCU_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCCU_MRKT_CODE','is_null', `SCCU_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCCU_NAME','is_null', `SCCU_NAME` IS NULL),
    named_struct('Column_Name','SCCU_VALUE','is_null', `SCCU_VALUE` IS NULL),
    named_struct('Column_Name','SCCU_CREATION_DT','is_null', `SCCU_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCCU_CREATION_UID','is_null', `SCCU_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCCU_UPDATE_DT','is_null', `SCCU_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCCU_UPDATE_UID','is_null', `SCCU_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumercustomattr as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCCU_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_terms WHERE SCTE_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCTE_ID','is_null', `SCTE_ID` IS NULL),
    named_struct('Column_Name','SCTE_SCON_ID','is_null', `SCTE_SCON_ID` IS NULL),
    named_struct('Column_Name','SCTE_MRKT_CODE','is_null', `SCTE_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_CODE','is_null', `SCTE_TERMS_CODE` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_DESCRIPTION','is_null', `SCTE_TERMS_DESCRIPTION` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_ACCEPT_DT','is_null', `SCTE_TERMS_ACCEPT_DT` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_VERSION','is_null', `SCTE_TERMS_VERSION` IS NULL),
    named_struct('Column_Name','SCTE_CREATION_DT','is_null', `SCTE_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCTE_CREATION_UID','is_null', `SCTE_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCTE_UPDATE_DT','is_null', `SCTE_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCTE_UPDATE_UID','is_null', `SCTE_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerterms").createOrReplaceGlobalTempView("sconsumerterms")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerterms as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCTE_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCTE_ID','is_null', `SCTE_ID` IS NULL),
    named_struct('Column_Name','SCTE_SCON_ID','is_null', `SCTE_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCTE_MRKT_CODE','is_null', `SCTE_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_CODE','is_null', `SCTE_TERMS_CODE` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_DESCRIPTION','is_null', `SCTE_TERMS_DESCRIPTION` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_ACCEPT_DT','is_null', `SCTE_TERMS_ACCEPT_DT` IS NULL),
    named_struct('Column_Name','SCTE_TERMS_VERSION','is_null', `SCTE_TERMS_VERSION` IS NULL),
    named_struct('Column_Name','SCTE_CREATION_DT','is_null', `SCTE_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCTE_CREATION_UID','is_null', `SCTE_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCTE_UPDATE_DT','is_null', `SCTE_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCTE_UPDATE_UID','is_null', `SCTE_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerterms as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCTE_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_remark WHERE SCRE_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCRE_ID','is_null', `SCRE_ID` IS NULL),
    named_struct('Column_Name','SCRE_SCON_ID','is_null', `SCRE_SCON_ID` IS NULL),
    named_struct('Column_Name','SCRE_MRKT_CODE','is_null', `SCRE_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCRE_RMAK_DT','is_null', `SCRE_RMAK_DT` IS NULL),
    named_struct('Column_Name','SCRE_RMAK_CODE','is_null', `SCRE_RMAK_CODE` IS NULL),
    named_struct('Column_Name','SCRE_RMAK_DESCRIPTION','is_null', `SCRE_RMAK_DESCRIPTION` IS NULL),
    named_struct('Column_Name','SCRE_CREATION_DT','is_null', `SCRE_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCRE_CREATION_UID','is_null', `SCRE_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCRE_UPDATE_DT','is_null', `SCRE_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCRE_UPDATE_UID','is_null', `SCRE_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerremark").createOrReplaceGlobalTempView("sconsumerremark")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerremark as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCRE_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCRE_ID','is_null', `SCRE_ID` IS NULL),
    named_struct('Column_Name','SCRE_SCON_ID','is_null', `SCRE_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCRE_MRKT_CODE','is_null', `SCRE_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCRE_RMAK_DT','is_null', `SCRE_RMAK_DT` IS NULL),
    named_struct('Column_Name','SCRE_RMAK_CODE','is_null', `SCRE_RMAK_CODE` IS NULL),
    named_struct('Column_Name','SCRE_RMAK_DESCRIPTION','is_null', `SCRE_RMAK_DESCRIPTION` IS NULL),
    named_struct('Column_Name','SCRE_CREATION_DT','is_null', `SCRE_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCRE_CREATION_UID','is_null', `SCRE_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCRE_UPDATE_DT','is_null', `SCRE_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCRE_UPDATE_UID','is_null', `SCRE_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerremark as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCRE_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_consumer_group WHERE SCGR_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCGR_ID','is_null', `SCGR_ID` IS NULL),
    named_struct('Column_Name','SCGR_SCON_ID','is_null', `SCGR_SCON_ID` IS NULL),
    named_struct('Column_Name','SCGR_MRKT_CODE','is_null', `SCGR_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCGR_CONSUMER_GRP','is_null', `SCGR_CONSUMER_GRP` IS NULL),
    named_struct('Column_Name','SCGR_CREATION_DT','is_null', `SCGR_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCGR_CREATION_UID','is_null', `SCGR_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCGR_UPDATE_DT','is_null', `SCGR_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCGR_UPDATE_UID','is_null', `SCGR_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumergroup").createOrReplaceGlobalTempView("sconsumergroup")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumergroup as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCGR_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCGR_ID','is_null', `SCGR_ID` IS NULL),
    named_struct('Column_Name','SCGR_SCON_ID','is_null', `SCGR_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCGR_MRKT_CODE','is_null', `SCGR_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCGR_CONSUMER_GRP','is_null', `SCGR_CONSUMER_GRP` IS NULL),
    named_struct('Column_Name','SCGR_CREATION_DT','is_null', `SCGR_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCGR_CREATION_UID','is_null', `SCGR_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCGR_UPDATE_DT','is_null', `SCGR_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCGR_UPDATE_UID','is_null', `SCGR_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumergroup as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCGR_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_notes WHERE SCNO_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCNO_ID','is_null', `SCNO_ID` IS NULL),
    named_struct('Column_Name','SCNO_SCON_ID','is_null', `SCNO_SCON_ID` IS NULL),
    named_struct('Column_Name','SCNO_MRKT_CODE','is_null', `SCNO_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCNO_SEQ_NUM','is_null', `SCNO_SEQ_NUM` IS NULL),
    named_struct('Column_Name','SCNO_TYPE_CODE','is_null', `SCNO_TYPE_CODE` IS NULL),
    named_struct('Column_Name','SCNO_LOCATION','is_null', `SCNO_LOCATION` IS NULL),
    named_struct('Column_Name','SCNO_NOTE','is_null', `SCNO_NOTE` IS NULL),
    named_struct('Column_Name','SCNO_CREATION_DT','is_null', `SCNO_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCNO_CREATION_UID','is_null', `SCNO_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCNO_UPDATE_DT','is_null', `SCNO_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCNO_UPDATE_UID','is_null', `SCNO_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumernotes").createOrReplaceGlobalTempView("sconsumernotes")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumernotes as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCNO_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCNO_ID','is_null', `SCNO_ID` IS NULL),
    named_struct('Column_Name','SCNO_SCON_ID','is_null', `SCNO_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCNO_MRKT_CODE','is_null', `SCNO_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCNO_SEQ_NUM','is_null', `SCNO_SEQ_NUM` IS NULL),
    named_struct('Column_Name','SCNO_TYPE_CODE','is_null', `SCNO_TYPE_CODE` IS NULL),
    named_struct('Column_Name','SCNO_LOCATION','is_null', `SCNO_LOCATION` IS NULL),
    named_struct('Column_Name','SCNO_NOTE','is_null', `SCNO_NOTE` IS NULL),
    named_struct('Column_Name','SCNO_CREATION_DT','is_null', `SCNO_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCNO_CREATION_UID','is_null', `SCNO_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCNO_UPDATE_DT','is_null', `SCNO_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCNO_UPDATE_UID','is_null', `SCNO_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumernotes as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCNO_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_hobby WHERE SCHO_MRKT_CODE NOT in ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCHO_ID','is_null', `SCHO_ID` IS NULL),
    named_struct('Column_Name','SCHO_SCON_ID','is_null', `SCHO_SCON_ID` IS NULL),
    named_struct('Column_Name','SCHO_MRKT_CODE','is_null', `SCHO_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCHO_HBBY_DESC','is_null', `SCHO_HBBY_DESC` IS NULL),
    named_struct('Column_Name','SCHO_CREATION_DT','is_null', `SCHO_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCHO_CREATION_UID','is_null', `SCHO_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCHO_UPDATE_DT','is_null', `SCHO_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCHO_UPDATE_UID','is_null', `SCHO_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerhobby").createOrReplaceGlobalTempView("sconsumerhobby")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerhobby as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCHO_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCHO_ID','is_null', `SCHO_ID` IS NULL),
    named_struct('Column_Name','SCHO_SCON_ID','is_null', `SCHO_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCHO_MRKT_CODE','is_null', `SCHO_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCHO_HBBY_DESC','is_null', `SCHO_HBBY_DESC` IS NULL),
    named_struct('Column_Name','SCHO_CREATION_DT','is_null', `SCHO_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCHO_CREATIONUID','is_null', `SCHO_CREATIONUID` IS NULL),
    named_struct('Column_Name','SCHO_UPDATE_DT','is_null', `SCHO_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCHO_UPDATE_UID','is_null', `SCHO_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerhobby as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCHO_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql
select * from catalog_southeastasia_mdm_silver_uat.history_data_loading.t_master_hobby

# %%
# %sql

desc history catalog_southeastasia_mdm_silver_uat.history_data_loading.t_master_hobby

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_skin_concerns WHERE SCSC_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCSC_ID','is_null', `SCSC_ID` IS NULL),
    named_struct('Column_Name','SCSC_SCON_ID','is_null', `SCSC_SCON_ID` IS NULL),
    named_struct('Column_Name','SCSC_MRKT_CODE','is_null', `SCSC_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCSC_SKINCONCERN_DESC','is_null', `SCSC_SKINCONCERN_DESC` IS NULL),
    named_struct('Column_Name','SCSC_CREATION_DT','is_null', `SCSC_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCSC_CREATION_UID','is_null', `SCSC_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCSC_UPDATE_DT','is_null', `SCSC_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCSC_UPDATE_UID','is_null', `SCSC_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerskinconcerns").createOrReplaceGlobalTempView("sconsumerskinconcerns")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerskinconcerns as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCSC_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCSC_ID','is_null', `SCSC_ID` IS NULL),
    named_struct('Column_Name','SCSC_SCON_ID','is_null', `SCSC_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCSC_MRKT_CODE','is_null', `SCSC_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCSC_SKINCONCERN_DESC','is_null', `SCSC_SKINCONCERN_DESC` IS NULL),
    named_struct('Column_Name','SCSC_CREATION_DT','is_null', `SCSC_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCSC_CREATION_UID','is_null', `SCSC_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCSC_UPDATE_DT','is_null', `SCSC_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCSC_UPDATE_UID','is_null', `SCSC_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerskinconcerns as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCSC_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_makeup_concerns WHERE SCMC_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCMC_ID','is_null', `SCMC_ID` IS NULL),
    named_struct('Column_Name','SCMC_SCON_ID','is_null', `SCMC_SCON_ID` IS NULL),
    named_struct('Column_Name','SCMC_MRKT_CODE','is_null', `SCMC_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCMC_MAKEUPCONCERN_DESC','is_null', `SCMC_MAKEUPCONCERN_DESC` IS NULL),
    named_struct('Column_Name','SCMC_CREATION_DT','is_null', `SCMC_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCMC_CREATION_UID','is_null', `SCMC_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCMC_UPDATE_DT','is_null', `SCMC_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCMC_UPDATE_UID','is_null', `SCMC_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumermakeupconcerns").createOrReplaceGlobalTempView("sconsumermakeupconcerns")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumermakeupconcerns as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCMC_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCMC_ID','is_null', `SCMC_ID` IS NULL),
    named_struct('Column_Name','SCMC_SCON_ID','is_null', `SCMC_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCMC_MRKT_CODE','is_null', `SCMC_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCMC_MAKEUPCONCERN_DESC','is_null', `SCMC_MAKEUPCONCERN_DESC` IS NULL),
    named_struct('Column_Name','SCMC_CREATION_DT','is_null', `SCMC_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCMC_CREATION_UID','is_null', `SCMC_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCMC_UPDATE_DT','is_null', `SCMC_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCMC_UPDATE_UID','is_null', `SCMC_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumermakeupconcerns as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCMC_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM  ${databricks_database}.t_master_hair_type WHERE SCHT_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCHT_ID','is_null', `SCHT_ID` IS NULL),
    named_struct('Column_Name','SCHT_SCON_ID','is_null', `SCHT_SCON_ID` IS NULL),
    named_struct('Column_Name','SCHT_MRKT_CODE','is_null', `SCHT_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCHT_HAIRTYPE','is_null', `SCHT_HAIRTYPE` IS NULL),
    named_struct('Column_Name','SCHT_CREATION_DT','is_null', `SCHT_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCHT_CREATION_UID','is_null', `SCHT_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCHT_UPDATE_DT','is_null', `SCHT_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCHT_UPDATE_UID','is_null', `SCHT_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerhairtype").createOrReplaceGlobalTempView("sconsumerhairtype")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerhairtype as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCHT_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCHT_ID','is_null', `SCHT_ID` IS NULL),
    named_struct('Column_Name','SCHT_SCON_ID','is_null', `SCHT_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCHT_MRKT_CODE','is_null', `SCHT_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCHT_HAIRTYPE','is_null', `SCHT_HAIRTYPE` IS NULL),
    named_struct('Column_Name','SCHT_CREATION_DT','is_null', `SCHT_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCHT_CREATION_UID','is_null', `SCHT_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCHT_UPDATE_DT','is_null', `SCHT_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCHT_UPDATE_UID','is_null', `SCHT_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerhairtype as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCHT_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_master_hair_concerns WHERE SCHC_MRKT_CODE NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','SCHC_ID','is_null', `SCHC_ID` IS NULL),
    named_struct('Column_Name','SCHC_SCON_ID','is_null', `SCHC_SCON_ID` IS NULL),
    named_struct('Column_Name','SCHC_MRKT_CODE','is_null', `SCHC_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCHC_HAIRCONCERN_DESC','is_null', `SCHC_HAIRCONCERN_DESC` IS NULL),
    named_struct('Column_Name','SCHC_CREATION_DT','is_null', `SCHC_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCHC_CREATION_UID','is_null', `SCHC_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCHC_UPDATE_DT','is_null', `SCHC_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCHC_UPDATE_UID','is_null', `SCHC_UPDATE_UID` IS NULL),
    named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_df(talend_snapshot_path, "sconsumerhairconcerns").createOrReplaceGlobalTempView("sconsumerhairconcerns")

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerhairconcerns as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCHC_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
),
kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM talend_base
  
  LATERAL VIEW posexplode(array(
   named_struct('Column_Name','SCHC_ID','is_null', `SCHC_ID` IS NULL),
    named_struct('Column_Name','SCHC_SCON_ID','is_null', `SCHC_SCON_ID` IS NULL),
    -- named_struct('Column_Name','SCHC_MRKT_CODE','is_null', `SCHC_MRKT_CODE` IS NULL),
    named_struct('Column_Name','SCHC_HAIRCONCERN_DESC','is_null', `SCHC_HAIRCONCERN_DESC` IS NULL),
    named_struct('Column_Name','SCHC_CREATION_DT','is_null', `SCHC_CREATION_DT` IS NULL),
    named_struct('Column_Name','SCHC_CREATION_UID','is_null', `SCHC_CREATION_UID` IS NULL),
    named_struct('Column_Name','SCHC_UPDATE_DT','is_null', `SCHC_UPDATE_DT` IS NULL),
    named_struct('Column_Name','SCHC_UPDATE_UID','is_null', `SCHC_UPDATE_UID` IS NULL)
    -- named_struct('Column_Name','BATCH_ID','is_null', `BATCH_ID` IS NULL),
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH 
talend_base AS
(select
  base_tab.*
from  
  global_temp.sconsumerhairconcerns as base_tab
left join
  global_temp.corss_talend_master_consumer_tab as cross_tab
on
  base_tab.database_name = cross_tab.database_name and
  base_tab.SCHC_SCON_ID = cross_tab.scon_id 
where
  coalesce(cross_tab.is_retain_for_history, true) !=  false 
)

SELECT count(*) FROM talend_base

# %%
# %sql

desc catalog_southeastasia_mdm_silver_uat.history_data_loading.t_cbrdrjart_dataset

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM ${databricks_cbr_database}.t_cbr_dataset
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','MarketCode','is_null', `MarketCode` IS NULL),
    named_struct('Column_Name','MDMKey','is_null', `MDMKey` IS NULL),
    named_struct('Column_Name','FinalJSON','is_null', `FinalJSON` IS NULL),
    named_struct('Column_Name','CreatedTimestamp','is_null', `CreatedTimestamp` IS NULL),
    named_struct('Column_Name','UpdatedTimestamp','is_null', `UpdatedTimestamp` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

select
    MarketCode, count(*)
from
    catalog_southeastasia_mdm_pr.consumer_combine.t_cbr_dataset
group by
    MarketCode

# %%
get_talend_cbr_df(talend_snapshot_path, "cbrl").createOrReplaceGlobalTempView("cbrl")

# %%
# %sql

select
    MarketCode, count(*)
from
    global_temp.cbrl
group by
    MarketCode

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM global_temp.cbrl
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','MarketCode','is_null', `MarketCode` IS NULL),
    named_struct('Column_Name','MDMKey','is_null', `MDMKey` IS NULL),
    named_struct('Column_Name','FinalJSON','is_null', `FinalJSON` IS NULL),
    named_struct('Column_Name','CreatedTimestamp','is_null', `CreatedTimestamp` IS NULL),
    named_struct('Column_Name','UpdatedTimestamp','is_null', `UpdatedTimestamp` IS NULL)
    -- ,
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql
select count(*) from global_temp.cbrl

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM ${databricks_cbr_database}.t_cbr_withoutPII_dataset
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','MarketCode','is_null', `MarketCode` IS NULL),
    named_struct('Column_Name','MDMKey','is_null', `MDMKey` IS NULL),
    named_struct('Column_Name','FinalJSON','is_null', `FinalJSON` IS NULL),
    named_struct('Column_Name','CreatedTimestamp','is_null', `CreatedTimestamp` IS NULL),
    named_struct('Column_Name','UpdatedTimestamp','is_null', `UpdatedTimestamp` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
get_talend_cbr_df(talend_snapshot_path, "cbrlpublic").createOrReplaceGlobalTempView("cbrlpublic")

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM global_temp.cbrlpublic
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','MarketCode','is_null', `MarketCode` IS NULL),
    named_struct('Column_Name','MDMKey','is_null', `MDMKey` IS NULL),
    named_struct('Column_Name','FinalJSON','is_null', `FinalJSON` IS NULL),
    named_struct('Column_Name','CreatedTimestamp','is_null', `CreatedTimestamp` IS NULL),
    named_struct('Column_Name','UpdatedTimestamp','is_null', `UpdatedTimestamp` IS NULL)
    -- ,
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql
select count(*) from global_temp.cbrlpublic

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM ${databricks_cbr_database}.t_cbrdrjart_dataset
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','MarketCode','is_null', `MarketCode` IS NULL),
    named_struct('Column_Name','MDMKey','is_null', `MDMKey` IS NULL),
    named_struct('Column_Name','FinalJSON','is_null', `FinalJSON` IS NULL),
    named_struct('Column_Name','CreatedTimestamp','is_null', `CreatedTimestamp` IS NULL),
    named_struct('Column_Name','UpdatedTimestamp','is_null', `UpdatedTimestamp` IS NULL),
    named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
spark.sql(f"select  * from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/cbrldrjart` ").createOrReplaceGlobalTempView("cbrldrjart")

# %%
# %sql

WITH kv AS (
  SELECT
    pos + 1 AS ord,
    x.Column_Name,
    x.is_null
  FROM global_temp.cbrldrjart
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','MarketCode','is_null', `MarketCode` IS NULL),
    named_struct('Column_Name','MDMKey','is_null', `MDMKey` IS NULL),
    named_struct('Column_Name','FinalJSON','is_null', `FinalJSON` IS NULL),
    named_struct('Column_Name','CreatedTimestamp','is_null', `CreatedTimestamp` IS NULL),
    named_struct('Column_Name','UpdatedTimestamp','is_null', `UpdatedTimestamp` IS NULL)
    -- ,
    -- named_struct('Column_Name','TASK_ID','is_null', `TASK_ID` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true  THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

select count(*) from global_temp.cbrldrjart

# %% [markdown]
# #checksum total count

# %%
# %sql

SELECT 't_master_consumer' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_consumer
UNION ALL
SELECT 't_master_address' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_address
UNION ALL
SELECT 't_master_auxiliary_attribute' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_auxiliary_attribute
UNION ALL
SELECT 't_master_consumer_group' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_consumer_group
UNION ALL
SELECT 't_master_crossbrand_optin' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_crossbrand_optin
UNION ALL
SELECT 't_master_custom_attributes' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_custom_attributes
UNION ALL
SELECT 't_master_emedia' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_emedia
UNION ALL
SELECT 't_master_hair_concerns' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_hair_concerns
UNION ALL
SELECT 't_master_hair_type' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_hair_type
UNION ALL
SELECT 't_master_hobby' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_hobby
UNION ALL
SELECT 't_master_makeup_concerns' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_makeup_concerns
UNION ALL
SELECT 't_master_notes' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_notes
UNION ALL
SELECT 't_master_optin' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_optin
UNION ALL
SELECT 't_master_phone' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_phone
UNION ALL
SELECT 't_master_program' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_program
UNION ALL
SELECT 't_master_remark' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_remark
UNION ALL
SELECT 't_master_skin_concerns' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_skin_concerns
UNION ALL
SELECT 't_master_terms' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_master_terms
UNION ALL
SELECT 't_cbr_dataset' AS table_name, COUNT(*) AS row_count FROM ${databricks_cbr_database}.t_cbr_dataset
UNION ALL
SELECT 't_cbr_withoutPII_dataset' AS table_name, COUNT(*) AS row_count FROM ${databricks_cbr_database}.t_cbr_withoutPII_dataset
UNION ALL
SELECT 't_cbrdrjart_dataset' AS table_name, COUNT(*) AS row_count FROM ${databricks_cbr_database}.t_cbrdrjart_dataset
UNION ALL
SELECT 't_transaction_master' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_transaction_master
UNION ALL
SELECT 't_sconsumermedia_line_unbind_records' AS table_name, COUNT(*) AS row_count FROM ${databricks_database}.t_sconsumermedia_line_unbind_records

# %%
excluder_conusmer_sql = f"""
     select  'aus_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'hkg_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'idn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'jpn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'kor_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'mys_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'nzl_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'phl_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

    select  'sgp_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

     select  'tha_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false union

    select  'twn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false 
     union

     select  'vnm_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history = false
"""

excluder_consumer_df = spark.sql(excluder_conusmer_sql)
print(excluder_consumer_df.count())

display(excluder_consumer_df)

# %%
add_conusmer_sql = f"""
     select  'aus_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/AUS/aus_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'hkg_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/HKG/hkg_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'idn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/IDN/idn_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'jpn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'kor_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/KOR/kor_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'mys_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/MYS/mys_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'nzl_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/NZL/nzl_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'phl_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/PHL/phl_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

    select  'sgp_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/SGP/sgp_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

     select  'tha_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false union

    select  'twn_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false 
     union

     select  'vnm_elcconsumermdm' as database_name,  {order_cols} from delta.`{talend_snapshot_path}/VNM/vnm_elcconsumermdm/sconsumer_cross_market` where is_retain_for_history != false
"""

add_consumer_df = spark.sql(add_conusmer_sql)
print(add_consumer_df.count())

display(add_consumer_df)

# %%
print(get_talend_df(talend_snapshot_path, "sconsumer").count())

# %%
spark.sql(f"select  * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/consumertransactionlist_rakuten` ").createOrReplaceGlobalTempView("consumertransactionlist_rakuten")

# spark.sql(f"select  * from delta.`{talend_snapshot_path}/TWN/twn_elcconsumermdm/consumertransactionlist_linegift` ").createOrReplaceGlobalTempView("consumertransactionlist_linegift")

# %%
# %sql

select 
    count(*)
from
(
    select * from global_temp.consumertransactionlist_rakuten
--     union
    -- select * from global_temp.consumertransactionlist_linegift
)

# %%
# %sql
-- select * from global_temp.consumertransactionlist_rakuten
-- union
select * from global_temp.consumertransactionlist_linegift

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (SELECT * FROM ${databricks_database}.t_transaction_master WHERE tran_mrkt_code NOT IN ('SGP', 'TWN'))
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','creation_dt','is_null', `creation_dt` IS NULL),
    named_struct('Column_Name','tran_action','is_null', `tran_action` IS NULL),

    named_struct('Column_Name','tran_brnd_code','is_null', `tran_brnd_code` IS NULL),
    named_struct('Column_Name','tran_id','is_null', `tran_id` IS NULL),
    named_struct('Column_Name','tran_mapping_consumer_id','is_null', `tran_mapping_consumer_id` IS NULL),
    named_struct('Column_Name','tran_mrkt_code','is_null', `tran_mrkt_code` IS NULL),
    named_struct('Column_Name','tran_order_id','is_null', `tran_order_id` IS NULL),

    named_struct('Column_Name','tran_srcc_id','is_null', `tran_srcc_id` IS NULL),
    named_struct('Column_Name','tran_srcs_code','is_null', `tran_srcs_code` IS NULL),
    named_struct('Column_Name','update_dt','is_null', `update_dt` IS NULL)

  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM (
    -- select * from global_temp.consumertransactionlist_rakuten
    -- union
    select * from global_temp.consumertransactionlist_rakuten
  )
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','scon_creation_dt','is_null', `scon_creation_dt` IS NULL),
    named_struct('Column_Name','scon_srcc_action','is_null', `scon_srcc_action` IS NULL),

    named_struct('Column_Name','scon_brnd_code','is_null', `scon_brnd_code` IS NULL),
    named_struct('Column_Name','scon_id','is_null', `scon_id` IS NULL),
    named_struct('Column_Name','consumermdmkey','is_null', `consumermdmkey` IS NULL),
    named_struct('Column_Name','scon_mrkt_code','is_null', `scon_mrkt_code` IS NULL),
    named_struct('Column_Name','scon_consumerid','is_null', `scon_consumerid` IS NULL),

    named_struct('Column_Name','scon_srcc_id','is_null', `scon_srcc_id` IS NULL),
    named_struct('Column_Name','scon_srcs_code','is_null', `scon_srcs_code` IS NULL),
    named_struct('Column_Name','scon_update_dt','is_null', `scon_update_dt` IS NULL)

  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM ${databricks_database}.t_transaction_master
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','creation_dt','is_null', `creation_dt` IS NULL),
    named_struct('Column_Name','tran_action','is_null', `tran_action` IS NULL),
    named_struct('Column_Name','tran_brnd_code','is_null', `tran_brnd_code` IS NULL),
    named_struct('Column_Name','tran_id','is_null', `tran_id` IS NULL),
    named_struct('Column_Name','tran_mapping_consumer_id','is_null', `tran_mapping_consumer_id` IS NULL),
    named_struct('Column_Name','tran_mrkt_code','is_null', `tran_mrkt_code` IS NULL),
    named_struct('Column_Name','tran_order_id','is_null', `tran_order_id` IS NULL),
    named_struct('Column_Name','tran_srcc_id','is_null', `tran_srcc_id` IS NULL),
    named_struct('Column_Name','tran_srcs_code','is_null', `tran_srcs_code` IS NULL),
    named_struct('Column_Name','update_dt','is_null', `update_dt` IS NULL)
  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
spark.sql(f"select  * from delta.`{talend_snapshot_path}/JPN/jpn_elcconsumermdm/line_unbind_exclusion` ").createOrReplaceGlobalTempView("line_unbind_exclusion")

# %%
spark.sql(f"select  * from delta.`{talend_snapshot_path}/THA/tha_elcconsumermdm/sconsumermedia_line_unbind_records` ").createOrReplaceGlobalTempView("sconsumermedia_line_unbind_records")

# %%
# %sql


select
    sum(coun)
from
(select count(*) as coun from global_temp.line_unbind_exclusion
union 
select count(*) as coun from global_temp.sconsumermedia_line_unbind_records
)

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM 
  (
  select scme_emdt_code, scme_sourcetimestamp, scme_address, scme_validitycode, scme_creation_dt, scme_update_dt from global_temp.line_unbind_exclusion
  union 
  select scme_emdt_code, scme_sourcetimestamp, scme_address, scme_validitycode, scme_creation_dt, scme_update_dt from global_temp.sconsumermedia_line_unbind_records
  )

  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','scme_emdt_code','is_null', `scme_emdt_code` IS NULL),
    named_struct('Column_Name','scme_sourcetimestamp','is_null', `scme_sourcetimestamp` IS NULL),

    named_struct('Column_Name','scme_address','is_null', `scme_address` IS NULL),
    named_struct('Column_Name','scme_validitycode','is_null', `scme_validitycode` IS NULL),

    named_struct('Column_Name','scme_creation_dt','is_null', `scme_creation_dt` IS NULL),
    named_struct('Column_Name','scme_update_dt','is_null', `scme_update_dt` IS NULL)

  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
# %sql

WITH kv AS (
  SELECT pos + 1 AS ord, x.Column_Name, x.is_null
  FROM ${databricks_database}.t_sconsumermedia_line_unbind_records
  LATERAL VIEW posexplode(array(
    named_struct('Column_Name','scme_emdt_code','is_null', `scme_emdt_code` IS NULL),
    named_struct('Column_Name','scme_sourcetimestamp','is_null', `scme_sourcetimestamp` IS NULL),

    named_struct('Column_Name','scme_address','is_null', `scme_address` IS NULL),
    named_struct('Column_Name','scme_validitycode','is_null', `scme_validitycode` IS NULL),

    named_struct('Column_Name','scme_creation_dt','is_null', `scme_creation_dt` IS NULL),
    named_struct('Column_Name','scme_update_dt','is_null', `scme_update_dt` IS NULL),

    named_struct('Column_Name','scme_market_code','is_null', `scme_market_code` IS NULL)

  )) pe AS pos, x
)
SELECT
  Column_Name,
  SUM(CASE WHEN is_null = false THEN 1 ELSE 0 END) AS With_Value,
  SUM(CASE WHEN is_null = true THEN 1 ELSE 0 END) AS null_Value
FROM kv
GROUP BY ord, Column_Name
ORDER BY ord;

# %%
spark.sql(f"select  * from delta.`{talend_snapshot_path}/HKG/hkg_mdmlanding/ssourcephoneapiresponse` ").createOrReplaceGlobalTempView("ssourcephoneapiresponse")

# %%
# %sql
select count(*) from global_temp.ssourcephoneapiresponse

# %%
get_talend_landing_data_sql = """

select  'aus_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/AUS/aus_mdmlanding/{table_name}` 
 union all
select  'hkg_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/HKG/hkg_mdmlanding/{table_name}` 
 union all
select  'idn_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/IDN/idn_mdmlanding/{table_name}` 
 union all  
select  'jpn_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/JPN/jpn_mdmlanding/{table_name}` 
 union all
select  'kor_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/KOR/kor_mdmlanding/{table_name}` 
 union all
select  'mys_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/MYS/mys_mdmlanding/{table_name}` 
 union all
select  'nzl_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/NZL/nzl_mdmlanding/{table_name}` 
 union all
select  'phl_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/PHL/phl_mdmlanding/{table_name}` 
 union all
select  'sgp_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/SGP/sgp_mdmlanding/{table_name}` 
 union all
select  'tha_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/THA/tha_mdmlanding/{table_name}` 
 union all
select  'twn_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/TWN/twn_mdmlanding/{table_name}` 
union all
select  'vnm_mdmlanding' as database_name, * from delta.`{talend_snapshot_path}/VNM/vnm_mdmlanding/{table_name}` 

"""

spark.sql(get_talend_landing_data_sql.format(talend_snapshot_path=talend_snapshot_path, table_name="slandconsumer") ).count()
