# %% [markdown]
# # Consumer

# %%
# %sql
create schema if not exists catalog_southeastasia_mdm_silver_prod.consumer_cleansed;

# %%
# %sql
use catalog_southeastasia_mdm_silver_prod.consumer_cleansed;

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_address (
  TASK_ID STRING,
  SRCA_ID STRING ,
  SRCA_SRCC_ID STRING ,
  SRCA_MRKT_CODE STRING,
  SRCA_ADDT_CODE STRING,
  SRCA_SOURCETIMESTAMP TIMESTAMP,
  SRCA_ADDRESS1 STRING,
  SRCA_ADDRESS2 STRING,
  SRCA_ADDRESS3 STRING,
  SRCA_CITY_LOCALDESC STRING,
  SRCA_PRVN_LOCALDESC STRING,
  SRCA_CNTR_ISOALPHA3CODE STRING,
  SRCA_POSTALCODE STRING,
  SRCA_VALIDITYCODE STRING,
  SRCA_PRIMARY_FLAG BOOLEAN,
  SRCA_CREATION_DT TIMESTAMP,
  SRCA_CREATIONUID STRING,
  SRCA_UPDATE_DT TIMESTAMP,
  SRCA_UPDATEUID STRING,
  SRCA_QUALITY_CODE STRING,
  SRCA_QUALITY_DESC STRING,
  SRCA_ADDRESS1_SOURCE STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_auxiliary_attribute (
  TASK_ID STRING,
  SRAA_ID STRING,
  SRAA_SRCC_ID STRING,
  SRAA_MRKT_CODE STRING,
  SRAA_CODE STRING,
  SRAA_DESC STRING,
  SRAA_MULTIVALUEFLAG BOOLEAN,
  SRAA_VALUE STRING,
  SRAA_ACTIVE_FLAG BOOLEAN,
  SRAA_CREATION_DT TIMESTAMP,
  SRAA_CREATIONUID STRING,
  SRAA_UPDATE_DT TIMESTAMP,
  SRAA_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_consumer (
  TASK_ID STRING,
  SRCC_ID STRING ,
  SRCC_ACTION STRING ,
  SRCC_DOCUMENTTIMESTAMP TIMESTAMP,
  SRCC_DOCUMENTUUID STRING,
  SRCC_RECORDUUID STRING ,
  SRCC_SRCS_CODE STRING ,
  SRCC_SOURCETIMESTAMP TIMESTAMP,
  SRCC_MRKT_CODE STRING ,
  SRCC_AFF_CODE STRING,
  SRCC_DVSN_CODE STRING,
  SRCC_BRND_CODE STRING ,
  SRCC_CONSUMERID STRING,
  SRCC_SALUTATION STRING,
  SRCC_ENGLISHFIRSTNAME STRING,
  SRCC_ENGLISHMIDDLENAME STRING,
  SRCC_ENGLISHLASTNAME STRING,
  SRCC_ENGLISHFULLNAME STRING,
  SRCC_LOCALFIRSTNAME STRING,
  SRCC_LOCALMIDDLENAME STRING,
  SRCC_LOCALLASTNAME STRING,
  SRCC_LOCALFULLNAME STRING,
  SRCC_LOCALFIRSTNAME2 STRING,
  SRCC_LOCALMIDDLENAME2 STRING,
  SRCC_LOCALLASTNAME2 STRING,
  SRCC_LOCALFULLNAME2 STRING,
  SRCC_GNDR_CODE STRING,
  SRCC_BIRTHDAY INT,
  SRCC_BIRTHMONTH INT,
  SRCC_BIRTHYEAR INT,
  SRCC_IDENTITYNUM STRING,
  SRCC_PASSPORTNUM STRING,
  SRCC_SOCIALSECURITYNUM STRING,
  SRCC_CLAS_CODE STRING,
  SRCC_REG_DT TIMESTAMP,
  SRCC_REGISTRATION_TOCH_CODE STRING ,
  SRCC_REGISTRATION_PRSN_CODE STRING,
  SRCC_PREFERRED_TOCH_CODE STRING,
  SRCC_ASSIGNED_PRSN_CODE STRING,
  SRCC_WLNG_CODE STRING,
  SRCC_SLNG_CODE STRING,
  SRCC_CNTR_ISOALPHA3CODE STRING,
  SRCC_ETHN_CODE STRING,
  SRCC_SKNT_CODE STRING,
  SRCC_HAIRT_CODE STRING,
  SRCC_CVLS_CODE STRING,
  SRCC_COMPANY STRING,
  SRCC_DEPARTMENT STRING,
  SRCC_JOBTITLE STRING,
  SRCC_YEARLYINCOME DECIMAL(10, 0),
  SRCC_DONOTCONTACT_FLAG BOOLEAN,
  SRCC_CURR_CODE STRING,
  SRCC_AGEFROM INT,
  SRCC_AGETO INT,
  SRCC_NATIONALITY STRING,
  SRCC_CHANNEL STRING,
  SRCC_PREFERRED_COMM_CHANNEL STRING,
  SRCC_ANNIVERSARY_DT DATE,

  -- talent没有取，但是表结构有，databricks取值
  SRCC_COMMERCIAL_FLAG BOOLEAN,

  SRCC_EMAILRECEIPT_FLAG BOOLEAN,
  SRCC_PROSPECT_FLAG BOOLEAN,
  SRCC_ACTIVE_FLAG BOOLEAN,
  SRCC_HRREQUESTTIMESTAMP TIMESTAMP,
  SRCC_STATUS STRING,
  SRCC_CREATION_DT TIMESTAMP,
  SRCC_CREATIONUID STRING,
  SRCC_UPDATE_DT TIMESTAMP,
  SRCC_UPDATEUID STRING,

  -- 没有地方用到，去掉这些字段
  -- English_Last_Name_Blocking_Key STRING,
  -- English_Name_Match_key STRING,
  -- Local_Name_Match_Key STRING,
  -- Local_Last_Name_Blocking_Key STRING,
  -- Email_Match_Key STRING,
  -- Mobile_Phone_match_Key STRING,
  -- Landline_Match_Key STRING,

  -- 清洗字段没用到，去掉这些字段
  -- SRCC_QUALITY_CODE STRING,
  -- SRCC_QUALITY_DESC STRING,
  
  SRCC_FIRSTPURCHASEDATE TIMESTAMP,

  SRCC_SALUTATION_SOURCE STRING,
  SRCC_ENGLISHFIRSTNAME_SOURCE STRING,
  SRCC_ENGLISHMIDDLENAME_SOURCE STRING,
  SRCC_ENGLISHLASTNAME_SOURCE STRING,
  SRCC_ENGLISHFULLNAME_SOURCE STRING,
  SRCC_LOCALFIRSTNAME_SOURCE STRING,
  SRCC_LOCALMIDDLENAME_SOURCE STRING,
  SRCC_LOCALLASTNAME_SOURCE STRING,
  SRCC_LOCALFULLNAME_SOURCE STRING,
  SRCC_LOCALFIRSTNAME2_SOURCE STRING,  -- 新增
  SRCC_LOCALMIDDLENAME2_SOURCE STRING,  -- 新增
  SRCC_LOCALLASTNAME2_SOURCE STRING,  -- 新增
  SRCC_LOCALFULLNAME2_SOURCE STRING,  -- 新增
  SRCC_BIRTHYEAR_SOURCE STRING,
  SRCC_WLNG_CODE_SOURCE STRING,
  SRCC_ENGLISHNAME_QUALITY_CODE STRING,
  SRCC_LOCALNAME_QUALITY_CODE STRING,
  SRCC_LOCALNAME2_QUALITY_CODE STRING,
  SRCC_UNIVERSALKEY STRING COMMENT 'LineBind&ACS UNIVERSALKEY',
  SRCC_MASTERCONSUMERID STRING COMMENT 'LineBind&ACS MASTERCONSUMERID',
  SRCC_SOURCESYSTEMCODE STRING COMMENT 'LineBind&ACS SOURCESYSTEMCODE',
  IS_INCLUDE BOOLEAN,
  EXCLUDE_TYPE STRING COMMENT '枚举值. ExcludeByPkMiss: 必填字段缺失; FailByClearMiss: 清洗模块缺失; ExcludeByConfig: 配置表排除',
  BATCH_ID STRING,
  BATCH_NUMBER STRING,
  RECORD_ID STRING COMMENT 'Step00数据清洗模块的记录唯一标识'
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_consumergroup (
  TASK_ID STRING,
  SRCG_ID STRING ,
  SRCG_SRCC_ID STRING,
  SRCG_MRKT_CODE STRING,
  SRCG_CONSUMER_GRP STRING,
  SRCG_CREATION_DT TIMESTAMP,
  SRCG_CREATIONUID STRING,
  SRCG_UPDATE_DT TIMESTAMP,
  SRCG_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_crossbrand_optin (
  TASK_ID STRING,
  SRBO_ID STRING ,
  SRBO_SRCC_ID STRING ,
  SRBO_MRKT_CODE STRING,
  SRBO_OPTIN_DT TIMESTAMP,
  SRBO_OPTIN_FLAG BOOLEAN,
  SRBO_CREATION_DT TIMESTAMP,
  SRBO_CREATIONUID STRING,
  SRBO_UPDATE_DT TIMESTAMP,
  SRBO_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_custom_attributes (
  TASK_ID STRING,
  SRAT_ID STRING,
  SRAT_SRCC_ID STRING,
  SRAT_MRKT_CODE STRING,
  SRAT_NAME STRING,
  SRAT_VALUE STRING,
  SRAT_CREATION_DT TIMESTAMP,
  SRAT_CREATIONUID STRING,
  SRAT_UPDATE_DT TIMESTAMP,
  SRAT_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_emedia (
  TASK_ID STRING,
  SRCE_ID STRING ,
  SRCE_SRCC_ID STRING ,
  SRCE_MRKT_CODE STRING,
  SRCE_EMDT_CODE STRING,
  SRCE_SOURCETIMESTAMP TIMESTAMP,
  SRCE_ADDRESS STRING,
  SRCE_VALIDITYCODE STRING,
  SRCE_PRIMARY_FLAG BOOLEAN,
  SRCE_APPID STRING,
  SRCE_CONTACTOPTINFLAG STRING,
  SRCE_REFERENCEEMEDIATYPECODE STRING,
  SRCE_REFERENCEEMEDIAADDRESS STRING,
  SRCE_CREATION_DT TIMESTAMP,
  SRCE_CREATIONUID STRING,
  SRCE_UPDATE_DT TIMESTAMP,
  SRCE_UPDATEUID STRING,
  SRCE_QUALITY_CODE STRING,
  SRCE_QUALITY_DESC STRING,
  SRCE_ADDRESS_SOURCE STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_hair_concerns (
  TASK_ID STRING,
  SRHC_ID STRING ,
  SRHC_SRCC_ID STRING ,
  SRHC_MRKT_CODE STRING,
  SRHC_CONCERN_DESC STRING,
  SRHC_CREATION_DT TIMESTAMP,
  SRHC_CREATIONUID STRING,
  SRHC_UPDATE_DT TIMESTAMP,
  SRHC_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_hair_type (
  TASK_ID STRING,
  SRHT_ID STRING ,
  SRHT_SRCC_ID STRING ,
  SRHT_MRKT_CODE STRING,
  SRHT_HAIRTYPE STRING,
  SRHT_CREATION_DT TIMESTAMP,
  SRHT_CREATIONUID STRING,
  SRHT_UPDATE_DT TIMESTAMP,
  SRHT_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_hobby (
  TASK_ID STRING,
  SRHB_ID STRING ,
  SRHB_SRCC_ID STRING,
  SRHB_MRKT_CODE STRING,
  SRHB_HBBY_DESC STRING,
  SRHB_CREATION_DT TIMESTAMP,
  SRHB_CREATIONUID STRING,
  SRHB_UPDATE_DT TIMESTAMP,
  SRHB_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_makeup_concerns (
  TASK_ID STRING,
  SRMC_ID STRING ,
  SRMC_SRCC_ID STRING ,
  SRMC_MRKT_CODE STRING,
  SRMC_CONCERN_DESC STRING,
  SRMC_CREATION_DT TIMESTAMP,
  SRMC_CREATIONUID STRING,
  SRMC_UPDATE_DT TIMESTAMP,
  SRMC_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_notes (
  TASK_ID STRING,
  SRNO_ID STRING ,
  SRNO_SRCC_ID STRING ,
  SRNO_MRKT_CODE STRING,
  SRNO_SEQ_NUM INT,
  SRNO_TYPE_CODE STRING,
  SRNO_LOCATION STRING,
  SRNO_NOTE STRING,
  SRNO_CREATION_DT TIMESTAMP,
  SRNO_CREATIONUID STRING,
  SRNO_UPDATE_DT TIMESTAMP,         
  SRNO_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_optin (
  TASK_ID STRING,
  SRCO_ID STRING ,
  SRCO_SRCC_ID STRING ,
  SRCO_MRKT_CODE STRING,
  SRCO_OPTIN_DT TIMESTAMP,
  SRCO_COMM_CODE STRING,
  SRCO_OPTIN_FLAG BOOLEAN,
  SRCO_CREATION_DT TIMESTAMP,
  SRCO_CREATIONUID STRING,
  SRCO_UPDATE_DT TIMESTAMP,
  SRCO_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_phone (
  TASK_ID STRING,
  SRCP_ID STRING ,
  SRCP_SRCC_ID STRING ,
  SRCP_MRKT_CODE STRING,
  SRCP_PHNT_CODE STRING,
  SRCP_SOURCETIMESTAMP TIMESTAMP,
  SRCP_PHONECOUNTRYCODE STRING,
  SRCP_PHONENUMBER STRING,
  SRCP_VALIDITYCODE STRING,
  SRCP_PRIMARY_FLAG BOOLEAN,
  SRCP_CREATION_DT TIMESTAMP,
  SRCP_CREATIONUID STRING,
  SRCP_UPDATE_DT TIMESTAMP,
  SRCP_UPDATEUID STRING,
  SRCP_QUALITY_CODE STRING,
  SRCP_QUALITY_DESC STRING,
  SRCP_PHONENUMBER_SOURCE STRING,
  SRCP_API_PHONENUMBER STRING,
  SRCP_API_SOUTHCHINESE_FLAG BOOLEAN,
  SRCP_API_DERIVED_PROVINCE STRING,
  SRCP_API_DERIVED_CITY STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_program (
  TASK_ID STRING,
  SRPG_ID STRING ,
  SRPG_SRCC_ID STRING ,
  SRPG_MRKT_CODE STRING,
  SRPG_APPLICATION_TOCH_CODE STRING,
  SRPG_CONSUMER_GRP STRING,
  SRPG_PRGT_CODE STRING,
  SRPG_PRGT_DESC STRING,
  SRPG_PRGL_CODE STRING,
  SRPG_PRGL_DESC STRING,
  SRPG_SYSTEM_CODE STRING,
  SRPG_SYSTEM_DESC STRING,
  SRPG_MEMBERSHIPNUM STRING,
  SRPG_CARDNUM STRING,
  SRPG_START_DT TIMESTAMP,
  SRPG_END_DT TIMESTAMP,
  SRPG_ACQUIREDPOINT_NUM DECIMAL(19, 4),
  SRPG_REDEEMEDPOINT_NUM DECIMAL(19, 4),
  SRPG_INITIAL_QUOTA DECIMAL(19, 4),
  SRPG_AVAILABLE_QUOTA DECIMAL(19, 4),
  SRPG_CPREDEEMED_NUM INT,
  SRPG_NEXTPOINTSEXPIRY_DT TIMESTAMP,
  SRPG_NEXTPOINTEXPIRY_NUM INT,
  SRPG_CURRENTYTD DECIMAL(10, 0),
  SRPG_P12SPEND DECIMAL(10, 0),
  SRPG_LIFETIME_SPEND DECIMAL(10, 0),
  SRPG_SPEND_TOUPGRADE DECIMAL(10, 0),
  SRPG_SPEND_TORENEW DECIMAL(10, 0),
  SRPG_CURRENTTIER_SPEND DECIMAL(10, 0),
  SRPG_TIERACHIEVED_DT TIMESTAMP,
  SRPG_PROGRAMNEXTRENEWAL_DT TIMESTAMP,
  SRPG_CREATION_DT TIMESTAMP,
  SRPG_CREATIONUID STRING,
  SRPG_UPDATE_DT TIMESTAMP,
  SRPG_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_remark (
  TASK_ID STRING,
  SRCR_ID STRING,
  SRCR_SRCC_ID STRING,
  SRCR_MRKT_CODE STRING,
  SRCR_RMAK_DT TIMESTAMP,
  SRCR_RMAK_CODE STRING,
  SRCR_RMAK_DESCRIPTION STRING,
  SRCR_CREATION_DT TIMESTAMP,
  SRCR_CREATIONUID STRING,
  SRCR_UPDATE_DT TIMESTAMP,
  SRCR_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_skin_concerns (
  TASK_ID STRING,
  SRSK_ID STRING ,
  SRSK_SRCC_ID STRING,
  SRSK_MRKT_CODE STRING,
  SRSK_CONCERN_DESC STRING,
  SRSK_CREATION_DT TIMESTAMP,
  SRSK_CREATIONUID STRING,
  SRSK_UPDATE_DT TIMESTAMP,
  SRSK_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_terms (
  TASK_ID STRING,
  SRCT_ID STRING ,
  SRCT_SRCC_ID STRING ,
  SRCT_MRKT_CODE STRING,
  SRCT_TERMS_CODE STRING,
  SRCT_TERMS_DESCRIPTION STRING,
  SRCT_TERMS_ACCEPT_DT TIMESTAMP,
  SRCT_TERMS_VERSION STRING,
  SRCT_CREATION_DT TIMESTAMP,
  SRCT_CREATIONUID STRING,
  SRCT_UPDATE_DT TIMESTAMP,
  SRCT_UPDATEUID STRING,
  -- IsValid STRING,
  -- Error_Message STRING,
  BATCH_ID STRING
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_ukey_group (
  task_id STRING,
  matc_id STRING,
  srcc_id STRING,
  mrkt_code STRING,
  brnd_code STRING,
  source_code STRING,
  consumer_id STRING,
  source_timestamp TIMESTAMP,
  master_scon_id STRING,
  master_consumermdmkey STRING,
  master_recode_create_time TIMESTAMP,
  is_master_recode BOOLEAN,
  new_consumermdmkey STRING,
  gid BIGINT,
  grp_size INT,
  batch_id STRING,
  match_type STRING COMMENT '枚举值: Regular_Ukey_Match, Acs&Line_Ukey_Match, Line_Ukey_Rebind',
  creation_dt TIMESTAMP
) CLUSTER BY (TASK_ID)

# %%
# %sql

CREATE OR REPLACE TABLE t_clean_ukey_edge (
  task_id STRING,
  src STRING,
  dst STRING,
  src_mrkt_code STRING,
  src_srcc_id STRING,
  dst_mrkt_code STRING,
  dst_srcc_id STRING,
  match_types STRING,
  creation_dt TIMESTAMP
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_cid_group (
  task_id STRING,
  matc_id STRING,
  srcc_id STRING,
  mrkt_code STRING,
  brnd_code STRING,
  source_code STRING,
  order_id STRING,
  source_timestamp TIMESTAMP,
  master_scon_id STRING,
  mapping_conusmer_id STRING,
  master_recode_create_time TIMESTAMP,
  new_mapping_conusmer_id STRING,
  record_type STRING COMMENT '',
  gid BIGINT,
  grp_size INT,
  batch_id STRING,
  match_type STRING COMMENT '枚举值:Line_Ukey_Rebind',
  creation_dt TIMESTAMP
) CLUSTER BY (TASK_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_clean_cid_edge (
  task_id STRING,
  src STRING,
  dst STRING,
  src_mrkt_code STRING,
  src_srcc_id STRING,
  dst_mrkt_code STRING,
  dst_srcc_id STRING,
  match_types STRING,
  creation_dt TIMESTAMP
) CLUSTER BY (TASK_ID)
