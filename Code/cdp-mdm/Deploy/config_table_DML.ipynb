-- %%
use catalog_southeastasia_mdm_share_prod.share_mdm_config;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
INSERT INTO t_topic_priority (Topic_Name, Priority, Is_Active) VALUES 
('ConsumerTopic_VL', 1, 1),
('Consumer_NZ_VL', 1, 1),
('Consumer_HK_VL', 1, 1),
('Consumer_ID_VL', 1, 1),
('Consumer_JP_VL', 1, 1),
('Consumer_KR_VL', 1, 1),
('Consumer_MY_VL', 1, 1),
('Consumer_PH_VL', 1, 1),
('Consumer_SG_VL', 1, 1),
('Consumer_TH_VL', 1, 1),
('Consumer_TW_VL', 1, 1),
('Consumer_VN_VL', 1, 1),
('Consumer_JP_Rakuten_VL', 1, 1),
('Consumer_TW_Linegift_VL', 1, 1),
('Consumer_History_VL', 5, 1);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>15</td><td>15</td></tr></tbody></table></div>

-- %%
INSERT INTO t_clean_condition (market_code, type, condition, is_active, create_time) VALUES 
('AUS', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('HKG', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('JPN', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('KOR', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('MYS', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('NZL', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('PHL', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('SGP', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('THA', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('TWN', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('VNM', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('IDN', 'Email', "SRCE_ADDRESS LIKE '%perf.elco.cloud%'", True, current_timestamp()),
('AUS', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('HKG', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('JPN', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('KOR', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('MYS', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('NZL', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('PHL', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('SGP', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('THA', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),

('TWN', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT', '不', '留') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT', '不', '留')", True, current_timestamp()),

('VNM', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp()),
('IDN', 'Consumer', "upper(srcc_localfullname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT') or upper(srcc_localfirstname) in ('DO NOT', 'DO NOT SHIP', 'TEST', 'TESTTEST', 'TEST TEST', 'DO  NOT')", True, current_timestamp());

-- ('AUS', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('HKG', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('JPN', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('KOR', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('MYS', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('NZL', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- -- ('PHL', 'Consumer', "SRCC_BRND_CODE = '99'", True, current_timestamp()),
-- ('PHL', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('SGP', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('THA', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('TWN', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('VNM', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp()),
-- ('IDN', 'Email', "right(SRCE_ADDRESS,15) = '%perf.elco.cloud%'", True, current_timestamp());
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>24</td><td>24</td></tr></tbody></table></div>

-- %%
-- 插入硬编码的排除sourcecode数据
INSERT INTO t_merge_exclude_consumer_config (tmec_id, tmec_type, tmec_marketcode, tmec_sourcesystemcode)
SELECT uuid(), 'ACS', 'AUS', 'undausundacsund' UNION ALL
SELECT uuid(), 'ACS', 'AUS', 'undanzundacsund' UNION ALL
SELECT uuid(), 'ACS', 'HKG', 'undhkgundacsund' UNION ALL
SELECT uuid(), 'ACS', 'IDN', 'undidnundacsund' UNION ALL
SELECT uuid(), 'LineBind', 'JPN', 'undapacundeformlineund' UNION ALL
SELECT uuid(), 'LineBind', 'JPN', 'undjpnundtcsmlsund' UNION ALL
SELECT uuid(), 'ACS', 'JPN', 'undjpnundacsund' UNION ALL
SELECT uuid(), 'ACS', 'JPN', 'undjpnundnlnund' UNION ALL
SELECT uuid(), 'ACS', 'KOR', 'undkorundacsund' UNION ALL
SELECT uuid(), 'ACS', 'MYS', 'undmysundacsund' UNION ALL
SELECT uuid(), 'ACS', 'NZL', 'undnzlundacsund' UNION ALL
SELECT uuid(), 'ACS', 'NZL', 'undanzundacsund' UNION ALL
SELECT uuid(), 'ACS', 'PHL', 'undphlundacsund' UNION ALL
SELECT uuid(), 'ACS', 'SGP', 'undsgpundacsund' UNION ALL
SELECT uuid(), 'LineBind', 'THA', 'undapacundeformlineund' UNION ALL
SELECT uuid(), 'LineBind', 'THA', 'undthaundlneonmbund' UNION ALL
SELECT uuid(), 'ACS', 'THA', 'undthaundacsund' UNION ALL
SELECT uuid(), 'LineBind', 'TWN', 'undtwnundlneikalaund' UNION ALL
SELECT uuid(), 'LineBind', 'TWN', 'undtwnundlneclbeund' UNION ALL
SELECT uuid(), 'ACS', 'TWN', 'undtwnundacsund' UNION ALL
SELECT uuid(), 'ACS', 'VNM', 'undvnmundacsund' UNION ALL
SELECT uuid(), 'Rakuten', 'JPN', 'undjpnundsskund' UNION ALL
SELECT uuid(), 'Rakuten', 'JPN', 'undjpnunditsumound' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn01lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn03lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn07lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn10lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn11lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn12lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn17lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn22lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn26lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn36lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn37lngftund' UNION ALL
SELECT uuid(), 'Linegift', 'TWN', '50twn38lngftund';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>35</td><td>35</td></tr></tbody></table></div>

-- %%
-- sconsumermediarejects
INSERT INTO t_merge_exclude_media_config (MarketCode, mediaAddress) VALUES
('HKG', '123@gmail.com'),
('HKG', '123@qq.com'),
('HKG', '123@yahoo.com'),
('HKG', '12345678@qq.com'),
('HKG', 'abc@gmail.com'),
('HKG', 'abc@hotmail.com'),
('HKG', 'arvindinelc@gmail.com'),
('HKG', 'cognizant.mac@gmail.com'),
('HKG', 'datanew14@gmail.com'),
('HKG', 'dummy@email.com'),
('HKG', 'dummy@gmail.com'),
('HKG', 'na@qq.com'),
('HKG', 'qq@qq.com'),
('HKG', 'qwertyui@qq.com'),
('HKG', 'test@gmail.com'),
('HKG', 'test@test.com'),
('HKG', 'wendy.xia@cognizant.com'),
('TWN', ''),
('TWN', ' '),
('TWN', '123@gmail.com'),
('TWN', '123@qq.com'),
('TWN', '12345678@qq.com'),
('TWN', 'abc@gmail.com'),
('TWN', 'abc@hotmail.com'),
('TWN', 'arvindinelc@gmail.com'),
('TWN', 'cognizant.mac@gmail.com'),
('TWN', 'datanew14@gmail.com'),
('TWN', 'dummy@email.com'),
('TWN', 'dummy@gmail.com'),
('TWN', 'na@qq.com'),
('TWN', 'qq@qq.com'),
('TWN', 'qwertyui@qq.com'),
('TWN', 'test@gmail.com'),
('TWN', 'test@test.com'),
('TWN', 'wendy.xia@cognizant.com');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>35</td><td>35</td></tr></tbody></table></div>

-- %%
-- tmatchexcludephone
INSERT INTO t_merge_exclude_phone_config (MarketCode, phoneNumber) VALUES
('HKG', '91552110'),
('JPN', '03-1234-1234'),
('JPN', '03-5354-0111'),
('JPN', '070-1234-1234');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>

-- %%
-- tmatchexcludeaddress
INSERT INTO t_merge_exclude_address_config (MarketCode, Address1) VALUES
('HKG', '顧客不願意留資料'),
('HKG', '不留'),
('HKG', '不寄'),
('HKG', 'NO'),
('HKG', 'NIL-NIL'),
('HKG', '-'),
('HKG', 'NA'),
('HKG', 'NIL'),
('HKG', 'NA-NA'),
('HKG', 'NIL-'),
('HKG', 'NIL-IL'),
('HKG', 'NIKL-NIL'),
('HKG', 'null-null'),
('HKG', '台北市中正區NO'),
('HKG', 'SHENZHEN CHINA'),
('HKG', 'CHINA'),
('HKG', '25 Canton Road 33/F'),
('HKG', 'MAINLAND CHINA'),
('HKG', 'HK'),
('HKG', 'GUANGZHOU CHINA'),
('HKG', 'SHENZHEN'),
('HKG', '中國大陸深圳'),
('HKG', 'Hong Kong'),
('HKG', 'NT'),
('HKG', 'SHANGHAI CHINA'),
('HKG', 'BEIJING CHINA'),
('HKG', 'DONGGUAN CHINA'),
('HKG', 'KLN'),
('HKG', '中國大陸 深圳'),
('HKG', 'WUHAN CHINA'),
('HKG', '深圳'),
('HKG', 'GUANGZHOU'),
('HKG', 'CHENGDU CHINA'),
('HKG', 'MACAU'),
('HKG', 'OTHER COUNTRY'),
('HKG', 'HK ISLAND'),
('HKG', 'CHONGQING CHINA'),
('HKG', 'Nathan Road'),
('HKG', 'ms'),
('HKG', '中國大陸'),
('HKG', 'adamsville'),
('HKG', 'ZHUHAI CHINA'),
('HKG', 'FOSHAN CHINA'),
('HKG', '中國大陸廣州'),
('HKG', 'SUZHOU CHINA'),
('HKG', 'CHI'),
('HKG', 'kowloon'),
('HKG', '中國大陸 浙江'),
('HKG', 'S'),
('HKG', 'JIANGMEN CHINA'),
('HKG', 'TIANJIN CHINA'),
('HKG', 'Tuen Mun'),
('HKG', '中國大陸深圳市'),
('HKG', '中國大陸 杭州'),
('HKG', '中國大陸 福建'),
('HKG', 'test'),
('HKG', 'SHANGHAI'),
('HKG', '.'),
('HKG', 'TKO'),
('HKG', '廣州'),
('HKG', '中國大陸 廣州'),
('HKG', '中國大陸 珠海'),
('HKG', 'Tin Shui Wai'),
('HKG', 'Tai PO'),
('HKG', 'tsuen wan'),
('HKG', 'c'),
('HKG', 'Shatin'),
('HKG', 'YUEN LONG'),
('HKG', 'ZHONGSHAN CHINA'),
('HKG', '`'),
('HKG', '中國大陸 湖南'),
('HKG', 'BEIJING'),
('HKG', 'DONGGUAN'),
('HKG', '中國大陸 南京'),
('HKG', 'g'),
('HKG', 'Ma On Shan'),
('HKG', 'tseung kwan o'),
('HKG', 'YING'),
('HKG', 'Fanling'),
('HKG', 'Kwun Tong'),
('HKG', 'YAN'),
('HKG', 'NEW TERRITORIES'),
('HKG', 'TSING YI'),
('HKG', '/'),
('HKG', '天水圍'),
('HKG', 'N/A'),
('HKG', '中國大陸 深圳市'),
('PHL', '顧客不願意留資料'),
('PHL', '不留'),
('PHL', '不寄'),
('PHL', 'NO'),
('PHL', 'NIL-NIL'),
('PHL', '-'),
('PHL', 'NA'),
('PHL', 'NIL'),
('PHL', 'NA-NA'),
('PHL', 'NIL-'),
('PHL', 'NIL-IL'),
('PHL', 'NIKL-NIL'),
('PHL', 'null-null'),
('SGP', '顧客不願意留資料'),
('SGP', '不留'),
('SGP', '不寄'),
('SGP', 'NO'),
('SGP', 'NIL-NIL'),
('SGP', '-'),
('SGP', 'NA'),
('SGP', 'NIL'),
('SGP', 'NA-NA'),
('SGP', 'NIL-'),
('SGP', 'NIL-IL'),
('SGP', 'NIKL-NIL'),
('SGP', 'null-null'),
('TWN', '顧客不願意留資料'),
('TWN', '不留'),
('TWN', '不寄'),
('TWN', 'NO'),
('TWN', 'NIL-NIL'),
('TWN', '-'),
('TWN', 'NA'),
('TWN', 'NIL'),
('TWN', 'NA-NA'),
('TWN', 'NIL-'),
('TWN', 'NIL-IL'),
('TWN', 'NIKL-NIL'),
('TWN', 'null-null'),
('TWN', '台北市中正區NO');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>127</td><td>127</td></tr></tbody></table></div>

-- %%
-- 初始化JPN的手机号排除数据
INSERT INTO t_merge_exclude_config (MarketCode, exclude_type, exclude_value) VALUES
('JPN', 'phoneNumber', '03-1234-1234'),
('JPN', 'phoneNumber', '03-5354-0111'),
('JPN', 'phoneNumber', '070-1234-1234');

-- 插入硬编码的排除数据
INSERT INTO t_merge_exclude_config (MarketCode, exclude_type, exclude_value) VALUES
-- AUS
('AUS', 'mediaAddress', 'test@test.com'),
('AUS', 'phoneNumber', '04'),
('AUS', 'phoneNumber', '1800613783'),
('AUS', 'phoneNumber', '61-0'),
('AUS', 'phoneNumber', '61-000'),
-- HKG
('HKG', 'mediaAddress', 'nil'),
('HKG', 'mediaAddress', 'dummy@email.com'),
('HKG', 'mediaAddress', 'n/a'),
('HKG', 'mediaAddress', '.'),
('HKG', 'mediaAddress', 'qq@qq.com'),
('HKG', 'mediaAddress', 'no email'),
('HKG', 'mediaAddress', 'dummy@gmail.com'),
('HKG', 'mediaAddress', 'NA@qq.com'),
('HKG', 'mediaAddress', '/'),
('HKG', 'mediaAddress', '3'),
('HKG', 'mediaAddress', '12345678@qq.com'),
('HKG', 'mediaAddress', '123@qq.com'),
('HKG', 'mediaAddress', 'na@gmail.com'),
('HKG', 'mediaAddress', 'qwertyui@qq.com'),
('HKG', 'mediaAddress', '12345@qq.com'),
('HKG', 'phoneNumber', '123456'),
('HKG', 'phoneNumber', 'CHI'),
('HKG', 'phoneNumber', '.'),
('HKG', 'phoneNumber', '0'),
('HKG', 'phoneNumber', 'C'),
('HKG', 'phoneNumber', '00000000'),
('HKG', 'phoneNumber', 'CH'),
('HKG', 'phoneNumber', '11111111'),
('HKG', 'phoneNumber', '853'),
('HKG', 'phoneNumber', '852-'),
('HKG', 'phoneNumber', 'Q'),
('HKG', 'phoneNumber', 'chin'),
('HKG', 'phoneNumber', '15000000000'),
-- IDN
('IDN', 'mediaAddress', 'test@test.com'),
('IDN', 'phoneNumber', '04'),
('IDN', 'phoneNumber', '1800613783'),
('IDN', 'phoneNumber', '61-0'),
('IDN', 'phoneNumber', '61-000'),
-- JPN
('JPN', 'mediaAddress', 'test@test.com'),
-- KOR
('KOR', 'mediaAddress', 'test@kr.estee.com'),
('KOR', 'phoneNumber', '－－---'),
('KOR', 'phoneNumber', '+82'),
('KOR', 'phoneNumber', '+8239'),
('KOR', 'phoneNumber', '02--'),
('KOR', 'phoneNumber', '+8213'),
-- MYS
('MYS', 'mediaAddress', '00'),
('MYS', 'mediaAddress', '00@gmail.com'),
('MYS', 'phoneNumber', '0'),
('MYS', 'phoneNumber', '00'),
('MYS', 'phoneNumber', '000'),
('MYS', 'phoneNumber', '0000'),
('MYS', 'phoneNumber', '1'),
-- NZL
('NZL', 'phoneNumber', '9-3030482'),
-- PHL
('PHL', 'mediaAddress', 'nil'),
('PHL', 'phoneNumber', '0'),
('PHL', 'phoneNumber', '0000000000'),
('PHL', 'phoneNumber', '0000000000Ext00000'),
('PHL', 'phoneNumber', '9472897332'),
('PHL', 'phoneNumber', '9'),
('PHL', 'phoneNumber', '002'),
('PHL', 'phoneNumber', '000000000000000'),
('PHL', 'phoneNumber', '917'),
('PHL', 'phoneNumber', '00000'),
-- SGP
('SGP', 'mediaAddress', '0'),
('SGP', 'mediaAddress', 'nil'),
('SGP', 'mediaAddress', 'NA'),
('SGP', 'mediaAddress', 'NO EMAIL'),
('SGP', 'mediaAddress', 'REFUSED'),
('SGP', 'mediaAddress', 'REFUSE'),
('SGP', 'mediaAddress', '.'),
('SGP', 'mediaAddress', 'NO'),
('SGP', 'mediaAddress', '1'),
('SGP', 'mediaAddress', 'NOEMAIL'),
('SGP', 'mediaAddress', '00'),
('SGP', 'mediaAddress', '*'),
('SGP', 'mediaAddress', 'N/L'),
('SGP', 'mediaAddress', '`'),
('SGP', 'mediaAddress', '+'),
('SGP', 'mediaAddress', 'nil@nil.com'),
('SGP', 'phoneNumber', '0'),
('SGP', 'phoneNumber', 'NA'),
('SGP', 'phoneNumber', '-'),
('SGP', 'phoneNumber', 'NIL'),
('SGP', 'phoneNumber', '1'),
('SGP', 'phoneNumber', '00'),
('SGP', 'phoneNumber', 'REFUSED'),
('SGP', 'phoneNumber', '.'),
('SGP', 'phoneNumber', '00000000'),
('SGP', 'phoneNumber', '65-'),
('SGP', 'phoneNumber', '0000000'),
('SGP', 'phoneNumber', '0000000 ext: 0000'),
('SGP', 'phoneNumber', 'refuse'),
('SGP', 'phoneNumber', '000'),
('SGP', 'phoneNumber', '0000'),
('SGP', 'phoneNumber', '6'),
('SGP', 'phoneNumber', '9'),
('SGP', 'phoneNumber', 'N.A'),
('SGP', 'phoneNumber', '000000'),
('SGP', 'phoneNumber', '123'),
('SGP', 'phoneNumber', '00000'),
('SGP', 'phoneNumber', '123456'),
('SGP', 'phoneNumber', '1234567'),
('SGP', 'phoneNumber', '12345678'),
('SGP', 'phoneNumber', '000000000'),
('SGP', 'phoneNumber', '90000000'),
('SGP', 'phoneNumber', '0000000000'),
('SGP', 'phoneNumber', '99999999'),
('SGP', 'phoneNumber', '='),
('SGP', 'phoneNumber', '2'),
('SGP', 'phoneNumber', 'O'),
('SGP', 'phoneNumber', '1234'),
('SGP', 'phoneNumber', '88888888'),
('SGP', 'phoneNumber', 'N/A'),
('SGP', 'phoneNumber', '0123123123'),
('SGP', 'phoneNumber', '7'),
('SGP', 'phoneNumber', '999'),
('SGP', 'phoneNumber', 'NULL'),
('SGP', 'phoneNumber', '9999999'),
('SGP', 'phoneNumber', '--'),
('SGP', 'phoneNumber', '11111111'),
('SGP', 'phoneNumber', 'N/L'),
('SGP', 'phoneNumber', '5'),
('SGP', 'phoneNumber', '9000000'),
('SGP', 'phoneNumber', '3'),
('SGP', 'phoneNumber', '8'),
('SGP', 'phoneNumber', '1111111'),
('SGP', 'phoneNumber', 'CANCELLED ACC'),
('SGP', 'phoneNumber', 'no'),
('SGP', 'phoneNumber', '123456789'),
('SGP', 'phoneNumber', '99999'),
('SGP', 'phoneNumber', '_'),
('SGP', 'phoneNumber', '11'),
('SGP', 'phoneNumber', '90121498'),
('SGP', 'phoneNumber', 'N'),
('SGP', 'phoneNumber', '4'),
('SGP', 'phoneNumber', 'X'),
('SGP', 'phoneNumber', '01'),
('SGP', 'phoneNumber', 'NILL'),
('SGP', 'phoneNumber', 'NONE'),
('SGP', 'phoneNumber', '111111111'),
-- THA
('THA', 'mediaAddress', 'xx'),
('THA', 'mediaAddress', '-'),
('THA', 'mediaAddress', 'no-e'),
('THA', 'mediaAddress', 'not filling'),
('THA', 'mediaAddress', 'not filled'),
('THA', 'mediaAddress', 'no'),
('THA', 'mediaAddress', 'n/a'),
('THA', 'mediaAddress', 'x'),
('THA', 'mediaAddress', 'xxx'),
('THA', 'phoneNumber', '02004917108'),
('THA', 'phoneNumber', '08'),
('THA', 'phoneNumber', '76223560'),
('THA', 'phoneNumber', 'XX'),
('THA', 'phoneNumber', '-'),
('THA', 'phoneNumber', '08896219788'),
-- TWN
('TWN', 'mediaAddress', 'abc@gmail.com'),
('TWN', 'mediaAddress', 'test@gmail.com'),
('TWN', 'phoneNumber', '886-'),
('TWN', 'phoneNumber', '+886-');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>159</td><td>159</td></tr></tbody></table></div>

-- %%
INSERT INTO t_survive_exclude_ukey_config (marketcode, consumermdmkey) VALUES
-- AUS 7
('AUS', '13e0070b-d593-4145-8645-49bac0798465'),
('AUS', '20d3fe5d-f4ce-46b0-a643-b02a9f1b1b60'),
('AUS', '43c4eb6c-2622-42a4-94e6-a3aed73b4d23'),
('AUS', '5481ea36-9cad-4459-beb6-45d46b898c9c'),
('AUS', '6e24763a-2c71-46f6-90ca-ef700cd09783'),
('AUS', '76396a73-4fd9-4dfb-a7cc-01a46f7b2e85'),
('AUS', 'aa0020c9-c894-49d4-8f58-20596ed19887'),
-- HKG 4
('HKG', '0ca43539-29b4-4377-a37e-9bdede09a10a'),
('HKG', '3ba4fdc3-db44-4af6-9d1f-c72849421d21'),
('HKG', '941f834b-cfd6-474d-aafb-8cdfd7e95186'),
('HKG', 'e6aeaa33-f9f8-4b5d-827e-04e271dbb1b6'),
-- MYS 8
('MYS', '5c2d16bc-efc0-49ce-a843-784e8d470eb1'),
('MYS', '5cfb0ff0-ee50-41ac-b609-30651d528dc3'),
('MYS', '601364d6-c910-464a-a100-6eeba99aa89b'),
('MYS', '6110386f-a603-499a-9f0c-0ec7d0f959e5'),
('MYS', '65ffad86-8b1d-4ae1-9f0d-28059ba76137'),
('MYS', '68cbb5e9-fa69-45a0-99ce-fc2c3987710a'),
('MYS', '6dd7ed60-2f9e-4f59-be81-3721d2801bf6'),
('MYS', '6dfed2db-a7ac-4184-a896-92f205f23e11'),
-- THA 14
('THA', '00051d17-065f-4ce3-b75a-2787209a463f'),
('THA', '06eac4a3-0a3e-4785-bcd1-a79d7db4fd6e'),
('THA', '0afad12a-353c-4356-9dfb-2a8f20436b38'),
('THA', '12582376-9d60-4271-8844-226e407887d5'),
('THA', '24670fd1-837b-4baa-8575-f0d6dc3ba3e2'),
('THA', '2ee7d1f8-5c34-4b0a-9b43-f48333353fcb'),
('THA', '4b3cccb7-2a10-4e4d-ba1f-18c32d58f844'),
('THA', '562e4668-b8d7-4139-b638-bf9584296c67'),
('THA', '60d3a4e9-95f7-4151-94e2-a34ea396901e'),
('THA', '92569ad5-3308-4c84-b1d0-b4f42ec1ecb0'),
('THA', '94b3cccb7-2a10-4e4d-ba1f-18c32d58f844'),
('THA', 'b13c470f-696c-489d-b33b-38d0d0a87559'),
('THA', 'dc24e606-452d-4c5d-ac6a-433a114f8cef'),

-- talend hard code
('AUS', '5fa8fc11-4ec3-4fc9-a57a-a8844ca7deec'),
('AUS', '83296f85-c49c-4583-8031-fa138f5f81e7'),
('AUS', '027864f9-e981-46f6-bf41-b54f28581f15'),
('AUS', 'e8d037d9-3679-45de-8150-ec784c7fd839'),
('AUS', '3e469e77-037f-42ba-8301-0e4ef973d0a5'),
('AUS', '4f14140d-1a26-40c1-a1b6-19dcdce54971'),
('AUS', 'fa2db2b9-4987-4b2b-9452-70670890e183'),
('AUS', 'fd557c73-0ecb-4edb-88fa-eba1ad3f0890'),
('AUS', 'dc918685-98b9-4c07-8420-5cabb8c0d395'),
('AUS', '1304defd-5aca-40b4-b97b-d80e23966ef3'),
('AUS', '90c0066a-5246-4185-9e01-8939e09f1751'),

('HKG', 'ee14ae3a-df0a-400b-8844-e964cd4c5a13'),
('HKG', 'ec201f2b-cdb3-4161-883f-5ac4ce65f3fc'),

('IDN', '5fa8fc11-4ec3-4fc9-a57a-a8844ca7deec'),
('IDN', '83296f85-c49c-4583-8031-fa138f5f81e7'),
('IDN', '027864f9-e981-46f6-bf41-b54f28581f15'),
('IDN', 'e8d037d9-3679-45de-8150-ec784c7fd839'),
('IDN', '3e469e77-037f-42ba-8301-0e4ef973d0a5'),
('IDN', '4f14140d-1a26-40c1-a1b6-19dcdce54971'),
('IDN', 'fa2db2b9-4987-4b2b-9452-70670890e183'),
('IDN', 'fd557c73-0ecb-4edb-88fa-eba1ad3f0890'),
('IDN', 'dc918685-98b9-4c07-8420-5cabb8c0d395'),
('IDN', '1304defd-5aca-40b4-b97b-d80e23966ef3'),
('IDN', '90c0066a-5246-4185-9e01-8939e09f1751'),

('JPN', 'ee14ae3a-df0a-400b-8844-e964cd4c5a13'),
('JPN', '83552c49-c2f0-485e-a1dd-04614c60111c'),

('MYS', '5fa8fc11-4ec3-4fc9-a57a-a8844ca7deec'),
('MYS', '83296f85-c49c-4583-8031-fa138f5f81e7'),
('MYS', '027864f9-e981-46f6-bf41-b54f28581f15'),
('MYS', 'e8d037d9-3679-45de-8150-ec784c7fd839'),
('MYS', '3e469e77-037f-42ba-8301-0e4ef973d0a5'),
('MYS', '4f14140d-1a26-40c1-a1b6-19dcdce54971'),
('MYS', 'fa2db2b9-4987-4b2b-9452-70670890e183'),
('MYS', 'fd557c73-0ecb-4edb-88fa-eba1ad3f0890'),
('MYS', 'dc918685-98b9-4c07-8420-5cabb8c0d395'),
('MYS', '1304defd-5aca-40b4-b97b-d80e23966ef3'),
('MYS', '90c0066a-5246-4185-9e01-8939e09f1751'),

('NZL', 'ee14ae3a-df0a-400b-8844-e964cd4c5a13'),
('NZL', '83552c49-c2f0-485e-a1dd-04614c60111c'),

('THA', '99669150-c777-4ca6-a185-723d854a068f'),

('TWN', 'ee14ae3a-df0a-400b-8844-e964cd4c5a13'),
('TWN', '83552c49-c2f0-485e-a1dd-04614c60111c')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>74</td><td>74</td></tr></tbody></table></div>

-- %%
INSERT INTO t_membership_program_code(MarketCode, prgt_code) VALUES 
 ('KOR', 'kor01kkg'),
 ('KOR', 'kor01nvr'),
 ('KOR', 'kor01ssg'),
 ('KOR', 'kor02kkg'),
 ('KOR', 'kor02nvr'),
 ('KOR', 'kor03kkg'),
 ('KOR', 'kor03nvr'),
 ('KOR', 'kor03ssg'),
 ('KOR', 'kor10kkg'),
 ('KOR', 'kor10nvr'),
 ('KOR', 'kor11kkg'),
 ('KOR', 'kor11nvr'),
 ('KOR', 'kor12kkg'),
 ('KOR', 'kor12ssg'),
 ('KOR', 'kor17kkg'),
 ('KOR', 'kor17ssg'),
 ('KOR', 'kor21kkg'),
 ('KOR', 'kor21nvr');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>18</td><td>18</td></tr></tbody></table></div>

-- %%
INSERT INTO t_cbr_exclude_program_code(MarketCode, prgt_code) VALUES 
 ('KOR', 'kor01kkg'),
 ('KOR', 'kor01nvr'),
 ('KOR', 'kor01ssg'),
 ('KOR', 'kor02kkg'),
 ('KOR', 'kor02nvr'),
 ('KOR', 'kor03kkg'),
 ('KOR', 'kor03nvr'),
 ('KOR', 'kor03ssg'),
 ('KOR', 'kor10kkg'),
 ('KOR', 'kor10nvr'),
 ('KOR', 'kor11kkg'),
 ('KOR', 'kor11nvr'),
 ('KOR', 'kor12kkg'),
 ('KOR', 'kor12ssg'),
 ('KOR', 'kor17kkg'),
 ('KOR', 'kor17ssg'),
 ('KOR', 'kor21kkg'),
 ('KOR', 'kor21nvr'),
 ('KOR', 'onldflt');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>19</td><td>19</td></tr></tbody></table></div>

-- %%
INSERT INTO downstream_config (
  config_id,
  downstream_type,
  downstream_mode,
  table_name,
  table_business_keys,
  marketcode,
  brandcode,
  condition_str,
  out_file_folder,
  out_file_name,
  is_split_file,
  split_row_count,
  value_map,
  include_fields,
  exclude_fields,
  is_backups,
  is_active,
  is_zip,
  is_encrypt,
  encrypt_config,
  kafka_topic_name,
  comment_str,
  create_time,
  create_user,
  update_time,
  update_user
)
VALUES
(1, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.touchpoint_combine.c_touchpoint_dataset', array('MarketCode','BrandCode','TouchPointCode'), 'All', 'All', "MarketCode != 'KOR' ", NULL, NULL, false, NULL, map('value', 'TouchPointMasterJSON', 'key', ' concat_ws("_", MarketCode,BrandCode,TouchPointCode) '), array('value', 'key'), NULL, false, true, false, NULL, NULL, 'TouchPointMaster', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod'),

(2, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.touchpoint_combine.c_touchpoint_dataset', array('MarketCode','BrandCode','TouchPointCode'), 'KOR', 'All', '1 = 1', NULL, NULL, false, NULL, map('value', 'TouchPointMasterJSON', 'key', ' concat_ws("_", MarketCode,BrandCode,TouchPointCode) '), array('value', 'key'), NULL, false, true, false, NULL, NULL, 'TouchPointMaster_KR', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod'),

(10, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'AUS', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'ConsumerBestRecordTopic', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(11, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'HKG', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_HK', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(12, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'IDN', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_ID', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(13, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'JPN', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_JP', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(14, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'KOR', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_KR', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(15, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'MYS', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_MY', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(16, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'NZL', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_NZ', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(17, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'PHL', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_PH', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(18, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'SGP', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_SG', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(19, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'THA', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_TH', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(20, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'TWN', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_TW', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(21, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_dataset', array('MarketCode','MDMKey'), 'VNM', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_VN', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),

(30, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'AUS', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublicTopic', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(31, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'HKG', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_HK', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(32, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'IDN', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_ID', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(33, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'JPN', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_JP', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(34, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'KOR', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_KR', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(35, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'MYS', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_MY', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(36, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'NZL', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_NZ', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(37, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'PHL', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_PH', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(38, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'SGP', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_SG', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(39, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'THA', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_TH', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(40, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'TWN', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_TW', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(41, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbr_withoutpii_dataset', array('MarketCode','MDMKey'), 'VNM', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBRPublic_VN', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(42, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_cbrdrjart_dataset', array('MarketCode','MDMKey'), 'KOR', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_DrJart_KR', 'prod', CAST('2026-04-17T06:26:48.153514Z' AS TIMESTAMP), 'prod', NULL, NULL),

(51, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_transaction_master_dataset', array('tran_mrkt_code','tran_id'), 'All', 'All', '1 = 1', NULL, NULL, NULL, NULL, map('value', 'json_str', 'key', 'tran_order_id'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'ConsumerMappingTopic', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),
(52, 'kafka', 'TC_INCR', 'catalog_southeastasia_mdm_share_prod.consumer_combine.c_membership_mapping_log', array('record_uuid'), 'All', 'All', '1 = 1', NULL, NULL, NULL, NULL, map('value','json_str', 'key', ' concat_ws("_", SRPG_MEMBERSHIPNUM,SRCC_CONSUMERID) '), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'ConsumerMappingTopic', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),



(501, 'kafka', 'FULL', 'catalog_southeastasia_mdm_share_prod.consumer_combine.t_cbrdrjart_dataset', array('MarketCode','MDMKey'), 'KOR', 'All', ' (octet_length(FinalJSON) < 5 * 1024 * 1024) ', NULL, NULL, NULL, NULL, map('value', 'FinalJSON', 'key', 'MDMKey'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'CBR_DrJart_KR', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),

(502, 'kafka', 'FULL', 'catalog_southeastasia_mdm_share_prod.consumer_combine.t_transaction_master_dataset', array('tran_mrkt_code','tran_id'), 'All', 'All', '1 = 1', NULL, NULL, NULL, NULL, map('value', 'json_str', 'key', 'tran_order_id'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'ConsumerMappingTopic', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL),

(503, 'kafka', 'FULL', 'catalog_southeastasia_mdm_share_prod.consumer_combine.t_membership_mapping_log', array('record_uuid'), 'All', 'All', 'rn = 1', NULL, NULL, NULL, NULL, map('value', 'json_str', 'key', ' concat_ws("_", SRPG_MEMBERSHIPNUM,SRCC_CONSUMERID) ', 'rn', 'ROW_NUMBER() OVER (PARTITION BY SRCC_MRKT_CODE, SRCC_BRND_CODE, SRCC_SRCS_CODE, SRPG_PRGT_CODE, SRPG_MEMBERSHIPNUM  ORDER BY SRCC_SOURCETIMESTAMP desc)'), array('value', 'key'), NULL, false, true, NULL, NULL, NULL, 'ConsumerMappingTopic', 'prod', CAST('2026-07-15T09:30:00.000Z' AS TIMESTAMP), 'prod', NULL, NULL);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>32</td><td>32</td></tr></tbody></table></div>

-- %%
INSERT INTO downstream_log (task_id, config_id, second_cdc_operation_time, comment_str, create_time, update_time)
VALUES
('1', '1', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('2', '2', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),

('10', '10', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('11', '11', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('12', '12', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('13', '13', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('14', '14', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('15', '15', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('16', '16', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('17', '17', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('18', '18', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('19', '19', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('20', '20', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('21', '21', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),

('30', '30', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('31', '31', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('32', '32', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('33', '33', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('34', '34', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('35', '35', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('36', '36', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('37', '37', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('38', '38', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('39', '39', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('40', '40', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('41', '41', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),

('42', '42', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('51', '51', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp()),
('52', '52', current_timestamp(), 'init for Prod', current_timestamp(), current_timestamp());
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>29</td><td>29</td></tr></tbody></table></div>
