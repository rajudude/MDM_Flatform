-- %%
use catalog_southeastasia_mdm_golden_prod.consumer_master;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- INSERT INTO dim_excludesource (id, sourcesystemcode, market_code) VALUES
-- (4, 'undanzundacsund', 'AUS'),
-- (3, 'undausundacsund', 'AUS'),
-- (1, 'undjpnundacsund', 'JPN'),
-- (2, 'undjpnundnlnund', 'JPN'),
-- (1, 'undhkgundacsund', 'HKG'),
-- (1, 'undkorundacsund', 'KOR'),
-- (1, 'undtwnundacsund', 'TWN');

-- %%
-- 相同表结构（迁移后共用一个新的表）
-- TWN tsourcesystemcodesurvivelatesttimestamp
-- HKG sourcesystemcodeoptintimestampchange
INSERT INTO t_sourcesystemcode_survive (sno, market_code, srcs_code) VALUES
(1, 'TWN', '50twn10lngftund'),
(2, 'TWN', '50twn01lngftund'),
(3, 'TWN', '50twn03lngftund'),
(4, 'TWN', '50twn07lngftund'),
(5, 'TWN', '50twn11lngftund'),
(6, 'TWN', '50twn12lngftund'),
(7, 'TWN', '50twn17lngftund'),
(8, 'TWN', '50twn22lngftund'),
(9, 'TWN', '50twn26lngftund'),
(10, 'TWN', '50twn36lngftund'),
(11, 'TWN', '50twn38lngftund'),
(12, 'TWN', '50twn37lngftund'),
(1, 'HKG', 'undapacunddcund');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>13</td><td>13</td></tr></tbody></table></div>
