# %% [markdown]
# # Consumer

# %%
# %sql
create schema if not exists catalog_southeastasia_mdm_golden_prod.consumer_master
# Out:
# I0715 01:45:03.771886  167235 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers

# %%
# %sql
use catalog_southeastasia_mdm_golden_prod.consumer_master

# %%
# %sql
-- CREATE TABLE dim_market (
--   MRKT_ID INT,
--   MRKT_CODE STRING NOT NULL,
--   MRKT_ALPHA2CODE STRING,
--   MRKT_ALPHA3CODE STRING,
--   MRKT_NUMCODE INT,
--   MRKT_DESC STRING
-- )
-- COMMENT 'market 手工表'

# %%
# %sql
-- CREATE TABLE dim_phone_country (
--   rc_phonecountrycode STRING,
--   rc_isocode2 STRING,
--   rc_isocode3 STRING,
--   rc_countryname STRING
-- )
-- COMMENT 'phone country 手工表'

# %%
# %sql
CREATE OR REPLACE TABLE t_master_consumer (
  TASK_ID STRING,
  SCON_ID STRING,
  SCON_SRCC_ID STRING ,
  SCON_SRCC_ACTION STRING,
  CONSUMERMDMKEY STRING,
  SCON_SRCS_CODE STRING ,
  SCON_SOURCETIMESTAMP TIMESTAMP,
  SCON_MRKT_CODE STRING ,
  SCON_AFF_CODE STRING,
  SCON_DVSN_CODE STRING,
  SCON_BRND_CODE STRING ,
  SCON_CONSUMERID STRING,
  SCON_SALUTATION STRING,
  SCON_ENGLISHFIRSTNAME STRING,
  SCON_ENGLISHMIDDLENAME STRING,
  SCON_ENGLISHLASTNAME STRING,
  SCON_ENGLISHFULLNAME STRING,
  SCON_LOCALFIRSTNAME STRING,
  SCON_LOCALMIDDLENAME STRING,
  SCON_LOCALLASTNAME STRING,
  SCON_LOCALFULLNAME STRING,
  SCON_LOCALFIRSTNAME2 STRING,
  SCON_LOCALMIDDLENAME2 STRING,
  SCON_LOCALLASTNAME2 STRING,
  SCON_LOCALFULLNAME2 STRING,
  SCON_GNDR_CODE STRING,
  SCON_BIRTHDAY INT,
  SCON_BIRTHMONTH INT,
  SCON_BIRTHYEAR INT,
  SCON_IDENTITYNUM STRING,
  SCON_PASSPORTNUM STRING,
  SCON_SOCIALSECURITYNUM STRING,
  SCON_CLAS_CODE STRING,
  SCON_REG_DT TIMESTAMP,
  SCON_REGISTRATION_TOCH_CODE STRING ,
  SCON_REGISTRATION_PRSN_CODE STRING,
  SCON_PREFERRED_TOCH_CODE STRING,
  SCON_ASSIGNED_PRSN_CODE STRING,
  SCON_WLNG_CODE STRING,
  SCON_SLNG_CODE STRING,
  SCON_CNTR_ISOALPHA3CODE STRING,
  SCON_ETHN_CODE STRING,
  SCON_SKNT_CODE STRING,
  SCON_HAIRT_CODE STRING,
  SCON_CVLS_CODE STRING,
  SCON_COMPANY STRING,
  SCON_DEPARTMENT STRING,
  SCON_JOBTITLE STRING,
  SCON_YEARLYINCOME DECIMAL(10, 0),
  SCON_DONOTCONTACT_FLAG BOOLEAN,
  SCON_CURR_CODE STRING,
  SCON_AGEFROM INT,
  SCON_AGETO INT,
  SCON_NATIONALITY STRING,
  SCON_CHANNEL STRING,
  SCON_PREFERRED_COMM_CHANNEL STRING,
  SCON_ANNIVERSARY_DT TIMESTAMP,
  SCON_COMMERCIAL_FLAG BOOLEAN,
  SCON_EMAILRECEIPT_FLAG BOOLEAN,
  SCON_PROSPECT_FLAG BOOLEAN,
  SCON_ACTIVE_FLAG BOOLEAN,
  SCON_HRREQUESTTIMESTAMP TIMESTAMP,
  SCON_STATUS STRING,
  SCON_CREATION_DT TIMESTAMP,
  SCON_CREATION_UID STRING,
  SCON_UPDATE_DT TIMESTAMP,
  SCON_UPDATE_UID STRING,
  SCON_CBR_FLAG BOOLEAN,
  SCON_FIRSTPURCHASEDATE TIMESTAMP,
  SCON_DELETE_FLAG BOOLEAN,
  SCON_ENGLISHNAME_QUALITY_CODE STRING,
  SCON_LOCALNAME_QUALITY_CODE STRING,
  SCON_LOCALNAME2_QUALITY_CODE STRING,
  SCON_UNIVERSALKEY STRING COMMENT 'LineBind&ACS UNIVERSALKEY',
  SCON_MASTERCONSUMERID STRING COMMENT 'LineBind&ACS MASTERCONSUMERID',
  SCON_SOURCESYSTEMCODE STRING COMMENT 'LineBind&ACS SOURCESYSTEMCODE',
  BATCH_ID STRING
)
CLUSTER BY (TASK_ID, SCON_MRKT_CODE, consumermdmkey)

# %%
# %sql
CREATE OR REPLACE TABLE t_master_address (
  SCAD_ID STRING,
  SCAD_SCON_ID STRING,
  SCAD_MRKT_CODE STRING,
  SCAD_ADDT_CODE STRING,
  SCAD_SOURCETIMESTAMP TIMESTAMP,
  SCAD_ADDRESS1 STRING,
  SCAD_ADDRESS2 STRING,
  SCAD_ADDRESS3 STRING,
  SCAD_CITY_LOCALDESC STRING,
  SCAD_PRVN_LOCALDESC STRING,
  SCAD_CNTR_ISOALPHA3CODE STRING,
  SCAD_POSTALCODE STRING,
  SCAD_VALIDITYCODE STRING,
  SCAD_PRIMARY_FLAG BOOLEAN,
  SCAD_QUALITY_CODE STRING,
  SCAD_QUALITY_DESC STRING,
  SCAD_CREATION_DT TIMESTAMP,
  SCAD_CREATION_UID STRING,
  SCAD_UPDATE_DT TIMESTAMP,
  SCAD_UPDATE_UID STRING,
  SCAD_UPDATE_FLAG BOOLEAN,
  BATCH_ID STRING,
  TASK_ID STRING
)
CLUSTER BY (SCAD_MRKT_CODE, SCAD_SCON_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_master_phone (
  SCPH_ID STRING,
  SCPH_SCON_ID STRING,
  SCPH_MRKT_CODE STRING,
  SCPH_PHNT_CODE STRING,
  SCPH_SOURCETIMESTAMP TIMESTAMP,
  SCPH_PHONECOUNTRYCODE STRING,
  SCPH_PHONENUMBER STRING,
  SCPH_VALIDITYCODE STRING,
  SCPH_PRIMARY_FLAG BOOLEAN,
  SCPH_QUALITY_CODE STRING,
  SCPH_QUALITY_DESC STRING,
  SCPH_CREATION_DT TIMESTAMP,
  SCPH_CREATION_UID STRING,
  SCPH_UPDATE_DT TIMESTAMP,
  SCPH_UPDATE_UID STRING,
  SCPH_UPDATE_FLAG BOOLEAN,
  BATCH_ID STRING,
  TASK_ID STRING
)
CLUSTER BY (SCPH_MRKT_CODE, SCPH_SCON_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_master_emedia (
  SCME_ID STRING,
  SCME_SCON_ID STRING,
  SCME_MRKT_CODE STRING,
  SCME_EMDT_CODE STRING,
  SCME_SOURCETIMESTAMP TIMESTAMP,
  SCME_ADDRESS STRING,
  SCME_VALIDITYCODE STRING,
  SCME_PRIMARY_FLAG BOOLEAN,
  SCME_APPID STRING,
  SCME_CONTACTOPTINFLAG STRING,
  SCME_REFERENCEEMEDIATYPECODE STRING,
  SCME_REFERENCEEMEDIAADDRESS STRING,
  SCME_QUALITY_CODE STRING,
  SCME_QUALITY_DESC STRING,
  SCME_CREATION_DT TIMESTAMP,
  SCME_CREATION_UID STRING,
  SCME_UPDATE_DT TIMESTAMP,
  SCME_UPDATE_UID STRING,
  SCME_UPDATE_FLAG BOOLEAN,
  BATCH_ID STRING,
  TASK_ID STRING
)
CLUSTER BY (SCME_MRKT_CODE, SCME_SCON_ID)

# %%
# %sql
CREATE OR REPLACE TABLE t_master_optin (
  SCOP_ID STRING,
  SCOP_SCON_ID STRING,
  SCOP_MRKT_CODE STRING,
  SCOP_OPTIN_DT TIMESTAMP,
  SCOP_COMM_CODE STRING,
  SCOP_OPTIN_FLAG BOOLEAN, 
  SCOP_CREATION_DT TIMESTAMP,
  SCOP_CREATION_UID STRING,
  SCOP_UPDATE_DT TIMESTAMP,
  SCOP_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)
CLUSTER BY (SCOP_MRKT_CODE, SCOP_SCON_ID)

# %%
# %sql
-- sconsumerauxiliaryattribute -> t_master_auxiliary_attribute
CREATE OR REPLACE TABLE t_master_auxiliary_attribute (
  SCAA_ID STRING,
  SCAA_SCON_ID STRING,
  SCAA_MRKT_CODE STRING,
  SCAA_CODE STRING,
  SCAA_DESC STRING,
  SCAA_MULTIVALUEFLAG BOOLEAN,
  SCAA_VALUE STRING,
  SCAA_ACTIVE_FLAG BOOLEAN,
  SCAA_CREATION_DT TIMESTAMP,
  SCAA_CREATION_UID STRING,
  SCAA_UPDATE_DT TIMESTAMP,
  SCAA_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerbeautyconcerns -> t_master_beauty_concerns apac 已废弃该表
-- CREATE OR REPLACE TABLE t_master_beauty_concerns (
--   SCBC_ID STRING,
--   SCBC_SCON_ID STRING,
--   SCBC_MRKT_CODE STRING,
--   SCBC_HAIRCONCERN_DESC STRING,
--   SCBC_MAKEUPCONCERN_DESC STRING,
--   SCBC_SKINCONCERN_DESC STRING,
--   SCBC_CREATION_DT TIMESTAMP,
--   SCBC_CREATION_UID STRING,
--   SCBC_UPDATE_DT TIMESTAMP,
--   SCBC_UPDATE_UID STRING,
--   BATCH_ID STRING,
--   TASK_ID STRING
-- )

# %%
# %sql
-- sconsumercrossbrandoptin -> t_master_crossbrand_optin
CREATE OR REPLACE TABLE t_master_crossbrand_optin (
  SCBO_ID STRING,
  SCBO_SCON_ID STRING,
  SCBO_MRKT_CODE STRING,
  SCBO_OPTIN_DT TIMESTAMP,
  SCBO_OPTIN_FLAG BOOLEAN,
  SCBO_CREATION_DT TIMESTAMP,
  SCBO_CREATION_UID STRING,
  SCBO_UPDATE_DT TIMESTAMP,
  SCBO_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumercustomattr -> t_master_custom_attributes
CREATE OR REPLACE TABLE t_master_custom_attributes (
  SCCU_ID STRING,
  SCCU_SCON_ID STRING,
  SCCU_MRKT_CODE STRING,
  SCCU_NAME STRING,
  SCCU_VALUE STRING,
  SCCU_CREATION_DT TIMESTAMP,
  SCCU_CREATION_UID STRING,
  SCCU_UPDATE_DT TIMESTAMP,
  SCCU_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumergroup -> t_master_consumergroup
CREATE OR REPLACE TABLE t_master_consumer_group (
  SCGR_ID STRING,
  SCGR_SCON_ID STRING,
  SCGR_MRKT_CODE STRING,
  SCGR_CONSUMER_GRP STRING,
  SCGR_CREATION_DT TIMESTAMP,
  SCGR_CREATION_UID STRING,
  SCGR_UPDATE_DT TIMESTAMP,
  SCGR_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerhairconcerns -> t_master_hair_concerns
CREATE OR REPLACE TABLE t_master_hair_concerns (
  SCHC_ID STRING,
  SCHC_SCON_ID STRING,
  SCHC_MRKT_CODE STRING,
  SCHC_HAIRCONCERN_DESC STRING,
  SCHC_CREATION_DT TIMESTAMP,
  SCHC_CREATION_UID STRING,
  SCHC_UPDATE_DT TIMESTAMP,
  SCHC_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerhairtype -> t_master_hair_type
CREATE OR REPLACE TABLE t_master_hair_type (
  SCHT_ID STRING,
  SCHT_SCON_ID STRING,
  SCHT_MRKT_CODE STRING,
  SCHT_HAIRTYPE STRING,
  SCHT_CREATION_DT TIMESTAMP,
  SCHT_CREATION_UID STRING,
  SCHT_UPDATE_DT TIMESTAMP,
  SCHT_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerhobby -> t_master_hobby
CREATE OR REPLACE TABLE t_master_hobby (
  SCHO_ID STRING,
  SCHO_SCON_ID STRING,
  SCHO_MRKT_CODE STRING,
  SCHO_HBBY_DESC STRING,
  SCHO_CREATION_DT TIMESTAMP,
  SCHO_CREATION_UID STRING,
  SCHO_UPDATE_DT TIMESTAMP,
  SCHO_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumermakeupconcerns -> t_master_makeup_concerns
CREATE OR REPLACE TABLE t_master_makeup_concerns (
  SCMC_ID STRING,
  SCMC_SCON_ID STRING,
  SCMC_MRKT_CODE STRING,
  SCMC_MAKEUPCONCERN_DESC STRING,
  SCMC_CREATION_DT TIMESTAMP,
  SCMC_CREATION_UID STRING,
  SCMC_UPDATE_DT TIMESTAMP,
  SCMC_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumernotes -> t_master_notes
CREATE OR REPLACE TABLE t_master_notes (
  SCNO_ID STRING,
  SCNO_SCON_ID STRING,
  SCNO_MRKT_CODE STRING,
  SCNO_SEQ_NUM INT,
  SCNO_TYPE_CODE STRING,
  SCNO_LOCATION STRING,
  SCNO_NOTE STRING,
  SCNO_CREATION_DT TIMESTAMP,
  SCNO_CREATION_UID STRING,
  SCNO_UPDATE_DT TIMESTAMP,
  SCNO_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerprogram -> t_master_program
CREATE OR REPLACE TABLE t_master_program (
  SCPR_ID STRING,
  SCPR_SCON_ID STRING,
  SCPR_MRKT_CODE STRING,
  SCPR_APPLICATION_TOCH_CODE STRING,
  SCPR_CONSUMER_GRP STRING,
  SCPR_PRGT_CODE STRING,
  SCPR_PRGT_DESC STRING,
  SCPR_PRGL_CODE STRING,
  SCPR_PRGL_DESC STRING,
  SCPR_SYSTEM_CODE STRING,
  SCPR_SYSTEM_DESC STRING,
  SCPR_MEMBERSHIPNUM STRING,
  SCPR_CARDNUM STRING,
  SCPR_START_DT TIMESTAMP,
  SCPR_END_DT TIMESTAMP,
  SCPR_ACQUIREDPOINT_NUM DECIMAL(19, 4),
  SCPR_REDEEMEDPOINT_NUM DECIMAL(19, 4),
  SCPR_INITIAL_QUOTA DECIMAL(19, 4),
  SCPR_AVAILABLE_QUOTA DECIMAL(19, 4),
  SCPR_CREATION_DT TIMESTAMP,
  SCPR_CREATION_UID STRING,
  SCPR_UPDATE_DT TIMESTAMP,
  SCPR_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerremark -> t_master_remark
CREATE OR REPLACE TABLE t_master_remark (
  SCRE_ID STRING,
  SCRE_SCON_ID STRING,
  SCRE_MRKT_CODE STRING,
  SCRE_RMAK_DT TIMESTAMP,
  SCRE_RMAK_CODE STRING,
  SCRE_RMAK_DESCRIPTION STRING,
  SCRE_CREATION_DT TIMESTAMP,
  SCRE_CREATION_UID STRING,
  SCRE_UPDATE_DT TIMESTAMP,
  SCRE_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerskinconcerns -> t_master_skin_concerns
CREATE OR REPLACE TABLE t_master_skin_concerns (
  SCSC_ID STRING,
  SCSC_SCON_ID STRING,
  SCSC_MRKT_CODE STRING,
  SCSC_SKINCONCERN_DESC STRING,
  SCSC_CREATION_DT TIMESTAMP,
  SCSC_CREATION_UID STRING,
  SCSC_UPDATE_DT TIMESTAMP,
  SCSC_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
-- sconsumerterms -> t_master_terms
CREATE OR REPLACE TABLE t_master_terms (
  SCTE_ID STRING,
  SCTE_SCON_ID STRING,
  SCTE_MRKT_CODE STRING,
  SCTE_TERMS_CODE STRING,
  SCTE_TERMS_DESCRIPTION STRING,
  SCTE_TERMS_ACCEPT_DT TIMESTAMP,
  SCTE_TERMS_VERSION STRING,
  SCTE_CREATION_DT TIMESTAMP,
  SCTE_CREATION_UID STRING,
  SCTE_UPDATE_DT TIMESTAMP,
  SCTE_UPDATE_UID STRING,
  BATCH_ID STRING,
  TASK_ID STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE t_derived_consumer_l1 (
  consumermdmkey STRING,
  scon_aff_code STRING,
  scon_mrkt_code STRING,
  scon_dvsn_code STRING,
  scon_brnd_code STRING,
  scon_srcs_code STRING,
  scon_sourcetimestamp TIMESTAMP,
  scon_gndr_code STRING,
  scon_birthday INT,
  scon_birthmonth INT,
  scon_birthyear INT,
  scon_reg_dt TIMESTAMP,
  scon_reg_sourcetimestamp TIMESTAMP,
  scon_registration_toch_code STRING,
  scon_prs_sourcesystemcode STRING,
  scon_prs_sourcetimestamp TIMESTAMP,
  scon_prs_aff_code STRING,
  scon_prs_mrkt_code STRING,
  scon_prs_dvsn_code STRING,
  scon_prs_brnd_code STRING,
  scon_registration_prsn_code STRING,
  scon_lastupdate_toch_code STRING,
  scon_wlng_code STRING,
  scon_slng_code STRING,
  scon_cntr_isoalpha3code STRING,
  scon_cvls_code STRING,
  namefilledflag STRING,
  RecordTimeStamp TIMESTAMP,
  RecordUUID STRING,
  SourceSystemJSON STRING,
  CustomAttributesJSON STRING,
  ProgramJSON STRING,
  header_action STRING comment 'databricks 新增字段, 用于cbr header json生成',
  UPDATE_DT TIMESTAMP,
  UPDATE_UID STRING,
  TASK_ID STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE t_derived_consumer_l2 (
  consumermdmkey STRING,
  scvlevel STRING,
  scon_srcs_code STRING,
  scon_sourcetimestamp TIMESTAMP,
  scon_mrkt_code STRING,
  scon_aff_code STRING,
  scon_dvsn_code STRING,
  scon_brnd_code STRING,
  scon_salutation STRING,
  scon_englishfirstname STRING,
  scon_englishmiddlename STRING,
  scon_englishlastname STRING,
  scon_englishfullname STRING,
  scon_localfirstname STRING,
  scon_localmiddlename STRING,
  scon_locallastname STRING,
  scon_localfullname STRING,
  scon_localfirstname2 STRING,
  scon_localmiddlename2 STRING,
  scon_locallastname2 STRING,
  scon_localfullname2 STRING,
  scon_gndr_code STRING,
  scon_birthday INT,
  scon_birthmonth INT,
  scon_birthyear INT,
  scon_identitynum STRING,
  scon_passportnum STRING,
  scon_socialsecuritynum STRING,
  scon_clas_code STRING,
  scon_reg_dt TIMESTAMP,
  scon_reg_sourcetimestamp TIMESTAMP,
  scon_registration_toch_code STRING,
  scon_prsn_srcs_code STRING,
  scon_prsn_sourcetimestamp TIMESTAMP,
  scon_prsn_aff_code STRING,
  scon_prsn_mrkt_code STRING,
  scon_prsn_dvsn_code STRING,
  scon_prsn_brnd_code STRING,
  scon_registration_prsn_code STRING,
  scon_last_update_timestamp TIMESTAMP,
  scon_last_update_toch_code STRING,
  scon_pre_toch_sourcetimestamp TIMESTAMP,
  scon_pre_toch_aff_code STRING,
  scon_pre_toch_mrkt_code STRING,
  scon_pre_toch_dvsn_code STRING,
  scon_pre_toch_brnd_code STRING,
  scon_preferred_toch_code STRING,
  scon_assn_prsn_srcs_code STRING,
  scon_assn_prsn_sourcetimestamp TIMESTAMP,
  scon_assn_prsn_aff_code STRING,
  scon_assn_prsn_mrkt_code STRING,
  scon_assn_prsn_dvsn_code STRING,
  scon_assn_prsn_brnd_code STRING,
  scon_assigned_prsn_code STRING,
  scon_wlng_code STRING,
  scon_slng_code STRING,
  scon_cntr_isoalpha3code STRING,
  scon_ethn_mrkt_code STRING,
  scon_ethn_code STRING,
  scon_sknt_brnd_code STRING,
  scon_sknt_code STRING,
  scon_hairt_code STRING,
  scon_cvls_code STRING,
  scon_company STRING,
  scon_department STRING,
  scon_jobtitle STRING,
  scon_yearlyincome DECIMAL(10, 0),
  scon_donotcontact_flag STRING,
  scon_curr_code STRING,
  scon_agefrom INT,
  scon_ageto INT,
  scon_nationality STRING,
  scon_channel STRING,
  scon_preferred_comm_channel STRING,
  scon_anniversary_dt TIMESTAMP,
  scon_commercial_flag STRING,
  scon_emailreceipt_flag STRING,
  scon_prospect_flag STRING,
  scon_active_flag STRING,
  scon_hrrequesttimestamp TIMESTAMP,
  scon_status STRING,
  namefilledflag STRING,
  RecordTimeStamp TIMESTAMP,
  DervivedBestRecordListID STRING,
  SourceSystemJSON STRING,
  HobbyJSON STRING,
  EMediaJSON STRING,
  PhoneJSON STRING,
  AddressJSON STRING,
  OptInJSON STRING,
  CrossBrandOptInJSON STRING,
  CustomAttributesJSON STRING,
  AuxiliaryAttributesJSON STRING,
  HairTypeJSON STRING,
  MakeUpConcernsJSON STRING,
  HairConcernsJSON STRING,
  SkinConcernsJSON STRING,
  TermsJSON STRING,
  ConsumerGroupJSON STRING,
  RemarkJSON STRING,
  NotesJSON STRING,
  scon_firstpurchasedate TIMESTAMP,
  UPDATE_DT TIMESTAMP,
  UPDATE_UID STRING,
  TASK_ID STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE t_derived_consumer_l3 (
  consumermdmkey STRING,
  scvlevel STRING,
  tcpm_distributionchannelcode STRING,
  scon_srcs_code STRING,
  scon_sourcetimestamp TIMESTAMP,
  scon_mrkt_code STRING,
  scon_aff_code STRING,
  scon_dvsn_code STRING,
  scon_brnd_code STRING,
  scon_salutation STRING,
  scon_englishfirstname STRING,
  scon_englishmiddlename STRING,
  scon_englishlastname STRING,
  scon_englishfullname STRING,
  scon_localfirstname STRING,
  scon_localmiddlename STRING,
  scon_locallastname STRING,
  scon_localfullname STRING,
  scon_localfirstname2 STRING,
  scon_localmiddlename2 STRING,
  scon_locallastname2 STRING,
  scon_localfullname2 STRING,
  scon_gndr_code STRING,
  scon_birthday INT,
  scon_birthmonth INT,
  scon_birthyear INT,
  scon_identitynum STRING,
  scon_passportnum STRING,
  scon_socialsecuritynum STRING,
  scon_clas_code STRING,
  scon_reg_dt TIMESTAMP,
  scon_reg_sourcetimestamp TIMESTAMP,
  scon_registration_toch_code STRING,
  scon_prsn_srcs_code STRING,
  scon_prsn_sourcetimestamp TIMESTAMP,
  scon_prsn_aff_code STRING,
  scon_prsn_mrkt_code STRING,
  scon_prsn_dvsn_code STRING,
  scon_prsn_brnd_code STRING,
  scon_registration_prsn_code STRING,
  scon_last_update_timestamp TIMESTAMP,
  scon_last_update_toch_code STRING,
  scon_pre_toch_sourcetimestamp TIMESTAMP,
  scon_pre_toch_aff_code STRING,
  scon_pre_toch_mrkt_code STRING,
  scon_pre_toch_dvsn_code STRING,
  scon_pre_toch_brnd_code STRING,
  scon_preferred_toch_code STRING,
  scon_assn_prsn_srcs_code STRING,
  scon_assn_prsn_sourcetimestamp TIMESTAMP,
  scon_assn_prsn_aff_code STRING,
  scon_assn_prsn_mrkt_code STRING,
  scon_assn_prsn_dvsn_code STRING,
  scon_assn_prsn_brnd_code STRING,
  scon_assigned_prsn_code STRING,
  scon_wlng_code STRING,
  scon_slng_code STRING,
  scon_cntr_isoalpha3code STRING,
  scon_ethn_mrkt_code STRING,
  scon_ethn_code STRING,
  scon_sknt_brnd_code STRING,
  scon_sknt_code STRING,
  scon_hairt_code STRING,
  scon_cvls_code STRING,
  scon_company STRING,
  scon_department STRING,
  scon_jobtitle STRING,
  scon_yearlyincome DECIMAL(10, 0),
  scon_donotcontact_flag STRING,
  scon_curr_code STRING,
  scon_agefrom INT,
  scon_ageto INT,
  scon_nationality STRING,
  scon_channel STRING,
  scon_preferred_comm_channel STRING,
  scon_anniversary_dt TIMESTAMP,
  scon_commercial_flag STRING,
  scon_emailreceipt_flag STRING,
  scon_prospect_flag STRING,
  scon_active_flag STRING,
  scon_hrrequesttimestamp TIMESTAMP,
  scon_status STRING,
  namefilledflag STRING,
  RecordTimeStamp TIMESTAMP,
  DervivedBestRecordListID STRING,
  SourceSystemJSON STRING,
  HobbyJSON STRING,
  EMediaJSON STRING,
  PhoneJSON STRING,
  AddressJSON STRING,
  OptInJSON STRING,
  CrossBrandOptInJSON STRING,
  CustomAttributesJSON STRING,
  AuxiliaryAttributesJSON STRING,
  HairTypeJSON STRING,
  MakeUpConcernsJSON STRING,
  HairConcernsJSON STRING,
  SkinConcernsJSON STRING,
  TermsJSON STRING,
  ConsumerGroupJSON STRING,
  RemarkJSON STRING,
  NotesJSON STRING,
  scon_firstpurchasedate TIMESTAMP,
  UPDATE_DT TIMESTAMP,
  UPDATE_UID STRING,
  TASK_ID STRING
)

# %%
# %sql
# CREATE OR REPLACE TABLE dimsrcspriority (
#   scon_srcs_code STRING,
#   srcs_touch_priority BIGINT
# )

# %%
# %sql
# CREATE OR REPLACE TABLE dim_excludesource (
#   id BIGINT,
#   sourcesystemcode STRING,
#   market_code STRING
# );

# %%
# %sql
-- 相同表结构（迁移后共用一个新的表）
-- TWN tsourcesystemcodesurvivelatesttimestamp
-- HKG sourcesystemcodeoptintimestampchange
CREATE OR REPLACE TABLE t_sourcesystemcode_survive (
    sno INT,
    market_code STRING, -- 新增market_code关联
    srcs_code STRING
)
USING DELTA

# %%
# %sql
-- JPN line_unbind_exclusion
-- 新逻辑, 该表合并至 t_sconsumermedia_line_unbind_records中

-- CREATE OR REPLACE TABLE t_line_unbind_exclusion (
--     scme_Line_id STRING,
--     scme_market_code STRING, -- 新增market_code关联
--     scme_scon_id STRING,
--     scme_emdt_code STRING,
--     scme_sourcetimestamp TIMESTAMP,
--     scme_address STRING,
--     scme_validitycode STRING,
--     scme_creation_dt TIMESTAMP,
--     scme_update_dt TIMESTAMP,
--     scon_srcc_action STRING,
--     scon_brnd_code STRING
-- )
-- USING DELTA;

# %%
# %sql
-- THA sconsumermedia_line_unbind_records
CREATE OR REPLACE TABLE t_sconsumermedia_line_unbind_records (
    scme_srcc_id STRING,
    scme_market_code STRING, -- 新增market_code关联
    scme_emdt_code STRING,
    scme_sourcetimestamp TIMESTAMP,
    scme_address STRING,
    scme_validitycode STRING,
    scme_primary_flag BOOLEAN,
    scme_appid STRING,
    scme_contactoptinflag STRING,
    scme_referenceemediatypecode STRING,
    scme_referenceemediaaddress STRING,
    scme_quality_code STRING,
    scme_quality_desc STRING,
    scme_creation_dt TIMESTAMP,
    scme_creation_uid STRING,
    scme_update_dt TIMESTAMP,
    scme_update_uid STRING,
    scme_update_flag BOOLEAN
)
USING DELTA

# %%
# %sql
-- THA sconsumermedia_unbind_history
-- 新逻辑去掉该表
-- CREATE OR REPLACE TABLE t_sconsumermedia_unbind_history (
--     scme_id STRING,
--     scme_scon_id STRING,
--     scme_market_code STRING, -- 新增market_code关联
--     scme_emdt_code STRING,
--     scme_sourcetimestamp TIMESTAMP,
--     scme_address STRING,
--     scme_validitycode STRING,
--     scme_primary_flag BOOLEAN,
--     scme_appid STRING,
--     scme_contactoptinflag STRING,
--     scme_referenceemediatypecode STRING,
--     scme_referenceemediaaddress STRING,
--     scme_quality_code STRING,
--     scme_quality_desc STRING,
--     scme_creation_dt TIMESTAMP,
--     scme_creation_uid STRING,
--     scme_update_dt TIMESTAMP,
--     scme_update_uid STRING,
--     scme_update_flag BOOLEAN
-- )
-- USING DELTA;

# %%
# %sql
CREATE OR REPLACE TABLE t_transaction_master (
  tran_id STRING,
  tran_mrkt_code STRING,
  tran_brnd_code STRING,
  tran_srcs_code STRING,
  tran_order_id STRING,
  tran_mapping_consumer_id STRING,
  tran_action STRING,
  tran_srcc_id STRING,
  task_id STRING,
  creation_dt TIMESTAMP,
  update_dt TIMESTAMP
)

# %% [markdown]
# # TouchPoint

# %%
# %sql
create schema if not exists catalog_southeastasia_mdm_golden_prod.touchpoint_master

# %%
# %sql
use catalog_southeastasia_mdm_golden_prod.touchpoint_master

# %%
# %sql
CREATE OR REPLACE TABLE t_touchpoint_master (
  TCPM_ID STRING,
  TCPM_TCPT_ID STRING,
  TCPM_Action STRING,
  TCPM_DocumentTimestamp STRING,
  TCPM_DocumentUUID STRING,
  TCPM_RecordUUID STRING,
  TCPM_SourceSystemCode STRING,
  TCPM_SourceTimestamp STRING,
  TCPM_MarketCode STRING,
  TCPM_AffiliateCode STRING,
  TCPM_DivisionCode STRING,
  TCPM_BrandCode STRING,
  TCPM_TouchPointCode STRING,
  TCPM_SubMarketCode STRING,
  TCPM_AuxiliaryCode STRING,
  TCPM_AuxiliaryTouchPointCode STRING,
  TCPM_HygieneServiceCode STRING,
  TCPM_DistributionChannelCode STRING,
  TCPM_TouchPointGroupCode STRING,
  TCPM_RetailerHierarchyCode STRING,
  TCPM_TouchPointTypeCode STRING,
  TCPM_EnglishDescription STRING,
  TCPM_LocalDescription STRING,
  TCPM_EnglishFullDescription STRING,
  TCPM_LocalFullDescription STRING,
  TCPM_Descriptionen STRING,
  TCPM_Descriptionlocal STRING,
  TCPM_FullDescriptionen STRING,
  TCPM_FullDescriptionlocal STRING,
  TCPM_URL STRING,
  TCPM_JDECode STRING,
  TCPM_Active STRING,
  TCPM_TouchPointStatus STRING,
  TCPM_OpenDate STRING,
  TCPM_BranchID STRING,
  TCPM_CustomerNumber STRING,
  TCPM_RedirectTouchPointCode STRING,
  TCPM_Channel STRING,
  TCPM_CustomerGroup STRING,
  TCPM_DTCFlag STRING,
  TCPM_Region STRING,
  TCPM_City STRING,
  TCPM_Attr_CustomAttributeList STRING,
  TCPM_PHONELIST STRING,
  TCPM_ADDRESSLIST STRING,
  TCPM_CUSTOMATTRIBUTELIST STRING,
  TCPM_TERMINALREGISTRATIONLIST STRING,
  TCPM_GLOBAL_Level STRING,
  TCPM_Global_Code STRING,
  TCPM_Global_Name STRING,
  TCPM_GLOBAL_DESCRIPTION STRING,
  TCPM_REGIONAL_Level STRING,
  TCPM_Regional_Code STRING,
  TCPM_Regional_Name STRING,
  TCPM_REGIONAL_DESCRIPTION STRING,
  TCPM_AFFILIATE_Level STRING,
  TCPM_Affiliate_Code STRING,
  TCPM_Affiliate_Name STRING,
  TCPM_AFFILIATE_DESCRIPTION STRING,
  TCPM_CREATION_DT TIMESTAMP,
  TCPM_CREATIONUID STRING,
  TCPM_UPDATE_DT TIMESTAMP,
  TCPM_UPDATEUID STRING,
  BATCH_ID STRING,
  KAFKA_TIMESTAMP TIMESTAMP
)
USING DELTA

# %%
# %sql
CREATE OR REPLACE TABLE t_touchpoint_master_sap (
  ID STRING,
  TCPT_ID STRING,
  TP_SAPBI_ID STRING,
  Action STRING,
  DocumentTimestamp STRING,
  DocumentUUID STRING,
  RecordUUID STRING,
  SourceSystemCode STRING,
  SourceTimestamp STRING,
  MarketCode STRING,
  AffiliateCode STRING,
  DivisionCode STRING,
  BrandCode STRING,
  TouchPointCode STRING,
  SubMarketCode STRING,
  AuxiliaryCode STRING,
  AuxiliaryTouchPointCode STRING,
  HygieneServiceCode STRING,
  DistributionChannelCode STRING,
  TouchPointGroupCode STRING,
  EnglishDescription STRING,
  LocalDescription STRING,
  EnglishFullDescription STRING,
  LocalFullDescription STRING,
  Descriptionen STRING,
  Descriptionlocal STRING,
  FullDescriptionen STRING,
  FullDescriptionlocal STRING,
  URL STRING,
  JDECode STRING,
  Active STRING,
  TouchPointStatus STRING,
  OpenDate STRING,
  BranchID STRING,
  CustomerNumber STRING,
  RedirectTouchPointCode STRING,
  CREATIONUID STRING,
  UPDATEUID STRING,
  creation_dt TIMESTAMP,
  update_dt TIMESTAMP,
  TouchPointTypeCode STRING,
  RetailerHierarchyCode STRING,
  CustomerGroup STRING,
  Region STRING,
  City STRING,
  Channel STRING,
  DTCFlag STRING,
  GLOBAL_Level STRING,
  Global_Code STRING,
  Global_Name STRING,
  GLOBAL_DESCRIPTION STRING,
  REGIONAL_Level STRING,
  Regional_Code STRING,
  Regional_Name STRING,
  REGIONAL_DESCRIPTION STRING,
  AFFILIATE_Level STRING,
  Affiliate_Code STRING,
  Affiliate_Name STRING,
  AFFILIATE_DESCRIPTION STRING,
  Attr_CustomAttributeList STRING,
  PHONELIST STRING,
  ADDRESSLIST STRING,
  CUSTOMATTRIBUTELIST STRING,
  TERMINALREGISTRATIONLIST STRING,
  KAFKA_TIMESTAMP TIMESTAMP
)
