# %%
# Step02
CONSUMER = "Consumer"
EMAIL = "Email"
PHONE = "Phone"
ADDRESS = "Address"

# Json Field:  @Action, DocumentTimestamp, DocumentUUID, @RecordUUID, @Code (SourceSystemCode), SourceTimestamp, MarketCode, BrandCode, ConsumerId, RegDate, RegTouchPointCode
CONSUMER_REQUIRED_FIELD = ["SRCC_ACTION", "SRCC_DOCUMENTTIMESTAMP", "SRCC_DOCUMENTUUID", "SRCC_RECORDUUID", "SRCC_SRCS_CODE", "SRCC_SOURCETIMESTAMP", "SRCC_MRKT_CODE", "SRCC_BRND_CODE", "SRCC_CONSUMERID", "SRCC_REG_DT", "SRCC_REGISTRATION_TOCH_CODE"]

# %%
# source type
# step04
SOURCE_TYPE_ACS = "ACS"
SOURCE_TYPE_LINEBIND = "LineBind"

# step02, step03
RAKUTEN = "Rakuten"
LINEGIFT = "Linegift"

# %%
# Step03
CID_MATCH_RECORD_TYPE_BATCH = "batch"
CID_MATCH_RECORD_TYPE_CM = "consumer_master"
# CID_MATCH_RECORD_TYPE_TM = "trans_master"

# %%
# Step04
MATCH_TYPE_REGULAR_STR = "Regular_Ukey_Match"
MATCH_TYPE_ACSLINE_STR = "Acs&Line_Ukey_Match"
MATCH_TYPE_REBIND_STR = "Line_Ukey_Rebind"

MATCH_TYPE_REGULAR_SPLIT_STR = "Regular_Split_Ukey_Match"
MATCH_TYPE_ACSLINE_SPLIT_STR = "Acs&Line_Split_Ukey_Match"

# %%
# Audit Columns
TOUCHPOINT_CREATION_UID = "MDMTouchopintjob_v1"
TOUCHPOINT_UPDATE_UID = "MDMTouchopintjob_v1"

# %%
# Step02
EXCLUDE_TYPE_BY_PK_MISS =  "ExcludeByPkMiss"
EXCLUDE_TYPE_BY_CLEAR_MISS = "FailByClearMiss"
EXCLUDE_TYPE_BY_CONFIG = "ExcludeByConfig"


# Step03
EXCLUDE_TYPE_BY_CID_DUPLICATE = "ExcludeByCidDuplicate"

# Step04
EXCLUDE_TYPE_BY_UID_DUPLICATE = "ExcludeByUidDuplicate"

# %%
# Data Anonymization: t_mdm_anonymization_log status
ANON_STATUS_IN_PROGRESS = "InProgress"
ANON_STATUS_COMPLETE = "Complete"

# Data Anonymization: cbr_type
ANON_CBR_TYPE_CBR = "cbr"
ANON_CBR_TYPE_CBRPUBLIC = "cbrpublic"
ANON_CBR_TYPE_CBRDJ = "cbrdj"
